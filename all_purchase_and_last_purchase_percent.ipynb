# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm as lgb

import feather
import warnings
import time
import sys
import datetime
import re
import gc

from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', 500)

from scipy.stats import mode
from scipy import stats
from sklearn import preprocessing


from IPython.core.display import display, HTML

# %%
all_transactions = feather.read_dataframe('all_transactions')

# %%
all_transactions['authorized_no'] = (all_transactions['authorized_flag'] == 0)

# %%
all_transactions['last_months_purchase'] = (all_transactions['payment_from_end_to_begging'] == 0)

# %%
purch_per_months = all_transactions.groupby(['card_id','payment_from_end_to_begging']).agg({'purchase_date':'count','authorized_no':'sum', 'authorized_flag':'sum', 'last_months_purchase':'sum'})

# %%
last_months_purchase_percent = purch_per_months.groupby(['card_id']).agg({'purchase_date':'sum','last_months_purchase':'max'})

# %%
last_months_purchase_percent['last_month_percent'] = last_months_purchase_percent['last_months_purchase'] / last_months_purchase_percent['purchase_date']

# %%
del last_months_purchase_percent['purchase_date']
# Out:
#                  last_months_purchase  last_month_percent
# card_id
# C_ID_00007093c1                   2.0            0.013245
# C_ID_0001238066                   9.0            0.060403
# C_ID_0001506ef0                   2.0            0.029412
# C_ID_0001793786                  10.0            0.040486
# C_ID_000183fdda                   3.0            0.019355
# C_ID_00024e244b                   2.0            0.028571
# C_ID_0002709b5a                   1.0            0.013158
# C_ID_00027503e2                   4.0            0.095238
# C_ID_000298032a                   1.0            0.032258
# C_ID_0002ba3c2e                   1.0            0.013699
# C_ID_0002c7c2c1                   3.0            0.041096
# C_ID_00032df08f                   8.0            0.052288
# C_ID_0003754056                   1.0            0.027027
# C_ID_000377f6a0                   1.0            0.034483
# C_ID_0003be3c83                   4.0            0.022599
# C_ID_0003f41435                   1.0            0.003774
# C_ID_00042d509c                   2.0            0.031250
# C_ID_0004587331                   2.0            0.125000
# C_ID_0004725b87                   2.0            0.025000
# C_ID_0004888ddd                   2.0            0.046512
# C_ID_0004b68c49                   1.0            0.142857
# C_ID_0004c2a5ab                   1.0            0.013333
# C_ID_00057b99fe                   1.0            0.027778
# C_ID_000599daf9                   4.0            0.090909
# C_ID_0005b2f279                   2.0            0.125000
# C_ID_0005b5804f                   1.0            0.125000
# C_ID_0005f16cc8                   1.0            0.006410
# C_ID_0006152db8                   1.0            0.011364
# C_ID_000616f4a8                   1.0            0.023256
# C_ID_000664aa02                   1.0            0.023256
# ...                               ...                 ...
# C_ID_fffb79fb56                   1.0            0.045455
# C_ID_fffb9ea3f6                  23.0            0.396552
# C_ID_fffba72dc5                   2.0            0.024096
# C_ID_fffbdf036b                   9.0            0.076271
# C_ID_fffbee5c24                   4.0            0.148148
# C_ID_fffc96bf24                   1.0            0.004545
# C_ID_fffcb74f49                   2.0            0.017857
# C_ID_fffcf66e12                   1.0            0.028571
# C_ID_fffd070e0e                   2.0            0.044444
# C_ID_fffd1207a8                   3.0            0.003708
# C_ID_fffd24dcf3                   7.0            0.304348
# C_ID_fffd337484                   4.0            0.105263
# C_ID_fffd345048                  13.0            0.151163
# C_ID_fffd351e7f                  15.0            0.057471
# C_ID_fffd93c8bf                  11.0            0.074830
# C_ID_fffd943b91                   1.0            0.014925
# C_ID_fffdad8aa0                   9.0            0.064748
# C_ID_fffde15ab6                   1.0            0.012048
# C_ID_fffdf34798                   4.0            0.064516
# C_ID_fffe29a04a                   3.0            0.032967
# C_ID_fffe78b232                   2.0            0.005525
# C_ID_fffe866457                   3.0            0.045455
# C_ID_fffea6de74                   4.0            0.009639
# C_ID_fffeced303                   1.0            0.005263
# C_ID_fffeed3a89                  23.0            0.105023
# C_ID_ffff1d9928                   3.0            0.187500
# C_ID_ffff579d3a                   1.0            0.008696
# C_ID_ffff756266                   1.0            0.040000
# C_ID_ffff828181                   5.0            0.025253
# C_ID_fffffd5772                   3.0            0.034483
#
# [325540 rows x 2 columns]

# %%
last_months_purchase_percent.reset_index(inplace=True)

# %%
purchases_description = purch_per_months.groupby(['card_id']).agg({'purchase_date':['max','mean','min','std','skew','sum'],
                                                                   'authorized_no':['max','mean','min','std','skew'],
                                                                   'authorized_flag':['max','mean','min','std','skew'],
                                                                  'last_months_purchase':'max'})

# %%
col_dict = {'purchase_date':'all_purchases',
            'authorized_no':'non_author_purchases',
            'authorized_flag':'author_purchases',
            'last_months_purchase':'last_months_purchase'}

# %%
purchases_description.columns = [f'{col_dict[x[0]]}_{x[1]}' for x in purchases_description]

# %%
purchases_description.head()
# Out:
#                  all_purchases_max  all_purchases_mean  all_purchases_min  \
# card_id
# C_ID_00007093c1                 19           10.785714                  2
# C_ID_0001238066                 37           18.625000                  2
# C_ID_0001506ef0                 18            4.857143                  1
# C_ID_0001793786                 38           20.583333                  2
# C_ID_000183fdda                 28           17.222222                  3
#
#                  all_purchases_std  all_purchases_skew  all_purchases_sum  \
# card_id
# C_ID_00007093c1           5.176553           -0.117048                151
# C_ID_0001238066          11.147549            0.125129                149
# C_ID_0001506ef0           4.435125            2.196911                 68
# C_ID_0001793786          13.069453           -0.088327                247
# C_ID_000183fdda          10.449615           -0.263454                155
#
#                  non_author_purchases_max  non_author_purchases_mean  \
# card_id
# C_ID_00007093c1                       6.0                   2.500000
# C_ID_0001238066                       2.0                   0.375000
# C_ID_0001506ef0                       2.0                   0.285714
# C_ID_0001793786                       8.0                   2.250000
# C_ID_000183fdda                       6.0                   0.777778
#
#                  non_author_purchases_min  non_author_purchases_std  \
# card_id
# C_ID_00007093c1                       0.0                  1.829250
# C_ID_0001238066                       0.0                  0.744024
# C_ID_0001506ef0                       0.0                  0.611250
# C_ID_0001793786                       0.0                  2.701010
# C_ID_000183fdda                       0.0                  1.986063
#
#                  non_author_purchases_skew  author_purchases_max  \
# card_id
# C_ID_00007093c1                   0.351881                    14
# C_ID_0001238066                   1.951030                    35
# C_ID_0001506ef0                   2.165284                    17
# C_ID_0001793786                   0.878176                    35
# C_ID_000183fdda                   2.854399                    28
#
#                  author_purchases_mean  author_purchases_min  \
# card_id
# C_ID_00007093c1               8.285714                     2
# C_ID_0001238066              18.250000                     2
# C_ID_0001506ef0               4.571429                     1
# C_ID_0001793786              18.333333                     2
# C_ID_000183fdda              16.444444                     0
#
#                  author_purchases_std  author_purchases_skew  \
# card_id
# C_ID_00007093c1              3.851644               0.019424
# C_ID_0001238066             10.620062              -0.013716
# C_ID_0001506ef0              4.237457               2.166954
# C_ID_0001793786             11.324417              -0.118318
# C_ID_000183fdda             11.314936              -0.369485
#
#                  last_months_purchase_max
# card_id
# C_ID_00007093c1                       2.0
# C_ID_0001238066                       9.0
# C_ID_0001506ef0                       2.0
# C_ID_0001793786                      10.0
# C_ID_000183fdda                       3.0

# %%
for x in [x for x in purchases_description if re.search('max|mean|min',x)]:
    purchases_description[x+'_percent'] = purchases_description[x] / purchases_description['all_purchases_sum']

# %%
purchases_description.reset_index(inplace=True)

# %%
purchases_description = pd.merge(purchases_description,last_months_purchase_percent,on='card_id',how='left')

# %%
purchases_description.head()
# Out:
#            card_id  all_purchases_max  all_purchases_mean  all_purchases_min  \
# 0  C_ID_00007093c1                 19           10.785714                  2
# 1  C_ID_0001238066                 37           18.625000                  2
# 2  C_ID_0001506ef0                 18            4.857143                  1
# 3  C_ID_0001793786                 38           20.583333                  2
# 4  C_ID_000183fdda                 28           17.222222                  3
#
#    all_purchases_std  all_purchases_skew  all_purchases_sum  \
# 0           5.176553           -0.117048                151
# 1          11.147549            0.125129                149
# 2           4.435125            2.196911                 68
# 3          13.069453           -0.088327                247
# 4          10.449615           -0.263454                155
#
#    non_author_purchases_max  non_author_purchases_mean  \
# 0                       6.0                   2.500000
# 1                       2.0                   0.375000
# 2                       2.0                   0.285714
# 3                       8.0                   2.250000
# 4                       6.0                   0.777778
#
#    non_author_purchases_min  non_author_purchases_std  \
# 0                       0.0                  1.829250
# 1                       0.0                  0.744024
# 2                       0.0                  0.611250
# 3                       0.0                  2.701010
# 4                       0.0                  1.986063
#
#    non_author_purchases_skew  author_purchases_max  author_purchases_mean  \
# 0                   0.351881                    14               8.285714
# 1                   1.951030                    35              18.250000
# 2                   2.165284                    17               4.571429
# 3                   0.878176                    35              18.333333
# 4                   2.854399                    28              16.444444
#
#    author_purchases_min  author_purchases_std  author_purchases_skew  \
# 0                     2              3.851644               0.019424
# 1                     2             10.620062              -0.013716
# 2                     1              4.237457               2.166954
# 3                     2             11.324417              -0.118318
# 4                     0             11.314936              -0.369485
#
#    last_months_purchase_max  all_purchases_max_percent  \
# 0                       2.0                   0.125828
# 1                       9.0                   0.248322
# 2                       2.0                   0.264706
# 3                      10.0                   0.153846
# 4                       3.0                   0.180645
#
#    all_purchases_mean_percent  all_purchases_min_percent  \
# 0                    0.071429                   0.013245
# 1                    0.125000                   0.013423
# 2                    0.071429                   0.014706
# 3                    0.083333                   0.008097
# 4                    0.111111                   0.019355
#
#    non_author_purchases_max_percent  non_author_purchases_mean_percent  \
# 0                          0.039735                           0.016556
# 1                          0.013423                           0.002517
# 2                          0.029412                           0.004202
# 3                          0.032389                           0.009109
# 4                          0.038710                           0.005018
#
#    non_author_purchases_min_percent  author_purchases_max_percent  \
# 0                               0.0                      0.092715
# 1                               0.0                      0.234899
# 2                               0.0                      0.250000
# 3                               0.0                      0.141700
# 4                               0.0                      0.180645
#
#    author_purchases_mean_percent  author_purchases_min_percent  \
# 0                       0.054872                      0.013245
# 1                       0.122483                      0.013423
# 2                       0.067227                      0.014706
# 3                       0.074224                      0.008097
# 4                       0.106093                      0.000000
#
#    last_months_purchase_max_percent  last_months_purchase  last_month_percent
# 0                          0.013245                   2.0            0.013245
# 1                          0.060403                   9.0            0.060403
# 2                          0.029412                   2.0            0.029412
# 3                          0.040486                  10.0            0.040486
# 4                          0.019355                   3.0            0.019355

# %%
len(re.search('([1-9|a-z](.*))','C_ID_000183fdda').group(0))
# Out:
# 7

# %%
purchases_description['card_id_lenght'] = purchases_description['card_id'].apply(lambda x: len(re.search('([1-9|a-z](.*))',x).group(0)))

# %%
feather.write_dataframe(purchases_description,'all_purchases_and_last_purch')
