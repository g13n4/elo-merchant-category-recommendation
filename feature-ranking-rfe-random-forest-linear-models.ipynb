# %% [markdown]
# #INTRODUCTION
#
# **Caveat** : Running this notebook will take a while if you do decide to fork so take note. A handful of minutes.
#
# This notebook will aim to provide an explanation and application of different feature ranking methods, namely that of Recursive Feature Elimination (RFE), Stability Selection, linear models as well as Random Forest. But first off, it is always imperative to give credit where credit is due. The stuff in this notebook is indebted to and borrows heavily from the excellent 4-part blog article by Ando Saabas on feature selection. So please do check out his article from this link: http://blog.datadive.net/selecting-good-features-part-iv-stability-selection-rfe-and-everything-side-by-side/
#
# The contents of this notebook are as follows:
#
#  1. **Data Cleaning and Visualisation** : This section will revolve around exploring the data and visualising some summary statistics.
#  2. **Stability Selection via Randomised Lasso Method** : Introduce a relatively new feature selection method called "Stability Selection" and using the Randomised Lasso in its implementation
#  3. **Recursive Feature Elimination** : Implementing the Recursive Feature Elimination method of feature ranking via the use of basic Linear Regression
#  4. **Linear Model Feature Coefficients** : Implementing 3 of Sklearn's linear models (Linear Regression, Lasso and Ridge) and using the inbuilt estimated coefficients for our feature selection
#  5. **Random Forest Feature Selection** : Using the Random Forest's convenient attribute "feature_importances" to calculate and ultimately rank the feature importance.
#
# Finally, with all the points 1 to 5 above, we will combine the results to create our:
#
# **Feature Ranking Matrix** : Matrix of all the features along with the respective model scores which we can use in our ranking.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.feature_selection import RFE, f_regression
from sklearn.linear_model import (LinearRegression, Ridge, Lasso, RandomizedLasso)
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
import feather

# %% [markdown]
# # 1. DATA CLEANSING AND ANALYSIS
#
# Let's first read in the house data as a dataframe "house" and inspect the first 5 rows

# %%
house = feather.read_dataframe('train')

# %% [markdown]
# Now its time for some general data inspection. Let's first examine to see if there are any nulls in the dataframe as well as look at the type of the data (i.e whether it is a string or numeric)

# %%
# Looking for nulls
print(house.isnull().any())
# Inspecting type
#print(house.dtypes)
# Out:
# feature_1                                      False
# feature_2                                      False
# feature_3                                      False
# elapsed_time                                   False
# agged_all_transactions_count                   False
# agged_all_category_1_sum                       False
# agged_all_category_1_mean                      False
# agged_all_purchase_date_year_quarter_mean      False
# agged_all_purchase_date_year_quarter_median    False
# agged_all_city_id_modeplus                     False
# agged_all_city_id_nunique                      False
# agged_all_installments_sum                     False
# agged_all_installments_mean                    False
# agged_all_installments_max                     False
# agged_all_installments_min                     False
# agged_all_installments_std                     False
# agged_all_installments_nunique                 False
# agged_all_merchant_category_id_modeplus        False
# agged_all_merchant_category_id_nunique         False
# agged_all_month_lag_mean                       False
# agged_all_month_lag_max                        False
# agged_all_month_lag_min                        False
# agged_all_month_lag_std                        False
# agged_all_purchase_amount_sum                  False
# agged_all_purchase_amount_mean                 False
# agged_all_purchase_amount_max                  False
# agged_all_purchase_amount_min                  False
# agged_all_purchase_amount_std                  False
# agged_all_state_id_modeplus                    False
# agged_all_state_id_nunique                     False
#                                                ...
# 20th_month_debt_bte_mean                       False
# 20th_month_debt_bte_std                        False
# 21th_month_debt_bte_sum                        False
# 21th_month_debt_bte_mean                       False
# 21th_month_debt_bte_std                        False
# 22th_month_debt_bte_sum                        False
# 22th_month_debt_bte_mean                       False
# 22th_month_debt_bte_std                        False
# 23th_month_debt_bte_sum                        False
# 23th_month_debt_bte_mean                       False
# 23th_month_debt_bte_std                        False
# 24th_month_debt_bte_sum                        False
# 24th_month_debt_bte_mean                       False
# 24th_month_debt_bte_std                        False
# 25th_month_debt_bte_sum                        False
# 25th_month_debt_bte_mean                       False
# 25th_month_debt_bte_std                        False
# 26th_month_debt_bte_sum                        False
# 26th_month_debt_bte_mean                       False
# 26th_month_debt_bte_std                        False
# 27th_month_debt_bte_sum                        False
# 27th_month_debt_bte_mean                       False
# 27th_month_debt_bte_std                        False
# 28th_month_debt_bte_sum                        False
# 28th_month_debt_bte_mean                       False
# 28th_month_debt_bte_std                        False
# last_purchase_month_bins                       False
# feature_1_pr                                   False
# feature_2_pr                                   False
# feature_3_pr                                   False
# Length: 655, dtype: bool

# %%
mpt = house.isnull().any()
mpt[mpt == True].index
# Out:
# Index(['eb_all_purchase_amount_std_mean_PM',
#        'eb_all_purchase_amount_std_std_PM', 'eb_all_installments_std_mean_PM',
#        'eb_all_installments_std_std_PM', 'ml_all_purchase_amount_std_mean_PM',
#        'ml_all_purchase_amount_std_std_PM', 'ml_all_installments_std_mean_PM',
#        'ml_all_installments_std_std_PM', 'eb_au_purchase_amount_std_mean_PM',
#        'eb_au_purchase_amount_std_std_PM',
#        ...
#        'agged_non_payment_from_end_to_begging_max',
#        'agged_non_payment_from_end_to_begging_min',
#        'agged_non_purchase_date_start_of_the_month_mean',
#        'agged_non_position_from_start_to_finnish_mean',
#        'agged_non_position_from_start_to_finnish_ptp',
#        'agged_non_position_from_start_to_finnish_max',
#        'agged_non_position_from_start_to_finnish_min',
#        'agged_non_debt_until_month_mean', 'agged_non_debt_until_month_std',
#        'agged_non_debt_until_month_ptp'],
#       dtype='object', length=191)

# %%
for x in mpt[mpt == True].index:
    house[x].fillna(0,inplace=True)

# %% [markdown]
# The data is pretty clean. There are no pesky nulls which we need to treat and most of the features are in numeric format. Let's go ahead and drop the "id" and "date" columns as these 2 features will not be used in this analysis.

# %%
# Dropping the id and date columns
house = house.drop(['card_id', 'first_active_month'],axis=1)

# %% [markdown]
# **Pairplot Visualisation**
#
# Let's create some Seaborn pairplots for the features ('sqft_lot','sqft_above','price','sqft_living','bedrooms') to get a feel for how the various features are distributed vis-a-vis the price as well as the number of bedrooms

# %%
#sns.pairplot(house[['sqft_lot','sqft_above','price','sqft_living','bedrooms']], hue='bedrooms', palette='afmhot',size=1.4)

# %%
with sns.plotting_context("notebook",font_scale=2.5):
    g = sns.pairplot(house[['sqft_lot','sqft_above','price','sqft_living','bedrooms']], 
                 hue='bedrooms', palette='tab20',size=6)
g.set(xticklabels=[]);

# %% [markdown]
# From the pairplots, we seem to get the classical linear distribution of the data points, for example with price against sqft_living. This bodes well as in the latter analysis, we will implement some linear models which we will use in our Feature ranking. Let's look at the correlation heatmap:

# %%
str_list = [] # empty list to contain columns with strings (words)
for colname, colvalue in house.iteritems():
    if type(colvalue[1]) == str:
         str_list.append(colname)
# Get to the numeric columns by inversion            
num_list = house.columns.difference(str_list) 
# Create Dataframe containing only numerical features
house_num = house[num_list]
f, ax = plt.subplots(figsize=(16, 12))
plt.title('Pearson Correlation of features')
# Draw the heatmap using seaborn
#sns.heatmap(house_num.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="PuBuGn", linecolor='k', annot=True)
sns.heatmap(house_num.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="cubehelix", linecolor='k', annot=True)

# %% [markdown]
# # 2. Stability Selection via Randomized Lasso
#
# In a nutshell, this method serves to apply the feature selection on different parts of the data and features repeatedly until the results can be aggregated. Therefore stronger features ( defined as being selected as important) will have greater scores in this method as compared to weaker features. Refer to this paper by Nicolai Meinshausen and Peter Buhlmann for a much greater detail on the method : http://stat.ethz.ch/~nicolai/stability.pdf
#
# In this notebook, the Stability Selection method is conveniently inbuilt into sklearn's randomized lasso model and therefore this will be implemented as follows:

# %%
# First extract the target variable which is our House prices
Y = pd.read_csv('target2',header=None,index_col=0).values
# Drop price from the house dataframe and create a matrix out of the house data
#house = house.drop(['price'], axis=1)
X = house.as_matrix()
# Store the column/feature names into a list "colnames"
colnames = house.columns
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %% [markdown]
# Next, we create a function which will be able to conveniently store our feature rankings obtained from the various methods described here into a Python dictionary. In case you are thinking I created this function, no this is not the case. All credit goes to Ando Saabas and I am only trying to apply what he has discussed in the context of this dataset.

# %%
# Define dictionary to store our rankings
ranks = {}
# Create our function which stores the feature rankings to the ranks dictionary
def ranking(ranks, names, order=1):
    minmax = MinMaxScaler()
    ranks = minmax.fit_transform(order*np.array([ranks]).T).T[0]
    ranks = map(lambda x: round(x,2), ranks)
    return dict(zip(names, ranks))

# %%
# Finally let's run our Selection Stability method with Randomized Lasso
rlasso = RandomizedLasso(alpha=0.04)
rlasso.fit(X, Y)
ranks["rlasso/Stability"] = ranking(np.abs(rlasso.scores_), colnames)
print('finished')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class RandomizedLasso is deprecated; The class RandomizedLasso is deprecated in 0.19 and will be removed in 0.21.
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# finished

# %% [markdown]
# # 3. Recursive Feature Elimination ( RFE )
#
# Now onto the next method in our feature ranking endeavour. Recursive Feature Elimination or RFE uses a model ( eg. linear Regression or SVM) to select either the best or worst-performing feature, and then excludes this feature. The whole process is then iterated until all features in the dataset are used up ( or up to a user-defined limit). Sklearn conveniently possesses a RFE function via the sklearn.feature_selection call and we will use this along with a simple linear regression model for our ranking search as follows:

# %%
# Construct our Linear Regression model
lr = LinearRegression(normalize=True)
lr.fit(X,Y)
#stop the search when only the last feature is left
rfe = RFE(lr, n_features_to_select=1, verbose =3 )
rfe.fit(X,Y)
ranks["RFE"] = ranking(list(map(float, rfe.ranking_)), colnames, order=-1)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:752: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting estimator with 655 features.
# Fitting estimator with 654 features.
# Fitting estimator with 653 features.
# Fitting estimator with 652 features.
# Fitting estimator with 651 features.
# Fitting estimator with 650 features.
# Fitting estimator with 649 features.
# Fitting estimator with 648 features.
# Fitting estimator with 647 features.
# Fitting estimator with 646 features.
# Fitting estimator with 645 features.
# Fitting estimator with 644 features.
# Fitting estimator with 643 features.
# Fitting estimator with 642 features.
# Fitting estimator with 641 features.
# Fitting estimator with 640 features.
# Fitting estimator with 639 features.
# Fitting estimator with 638 features.
# Fitting estimator with 637 features.
# Fitting estimator with 636 features.
# Fitting estimator with 635 features.
# Fitting estimator with 634 features.
# Fitting estimator with 633 features.
# Fitting estimator with 632 features.
# Fitting estimator with 631 features.
# Fitting estimator with 630 features.
# Fitting estimator with 629 features.
# Fitting estimator with 628 features.
# Fitting estimator with 627 features.
# Fitting estimator with 626 features.
# Fitting estimator with 625 features.
# Fitting estimator with 624 features.
# Fitting estimator with 623 features.
# Fitting estimator with 622 features.
# Fitting estimator with 621 features.
# Fitting estimator with 620 features.
# Fitting estimator with 619 features.
# Fitting estimator with 618 features.
# Fitting estimator with 617 features.
# Fitting estimator with 616 features.
# Fitting estimator with 615 features.
# Fitting estimator with 614 features.
# Fitting estimator with 613 features.
# Fitting estimator with 612 features.
# Fitting estimator with 611 features.
# Fitting estimator with 610 features.
# Fitting estimator with 609 features.
# Fitting estimator with 608 features.
# Fitting estimator with 607 features.
# Fitting estimator with 606 features.
# Fitting estimator with 605 features.
# Fitting estimator with 604 features.
# Fitting estimator with 603 features.
# Fitting estimator with 602 features.
# Fitting estimator with 601 features.
# Fitting estimator with 600 features.
# Fitting estimator with 599 features.
# Fitting estimator with 598 features.
# Fitting estimator with 597 features.
# Fitting estimator with 596 features.
# Fitting estimator with 595 features.
# Fitting estimator with 594 features.
# Fitting estimator with 593 features.
# Fitting estimator with 592 features.
# Fitting estimator with 591 features.
# Fitting estimator with 590 features.
# Fitting estimator with 589 features.
# Fitting estimator with 588 features.
# Fitting estimator with 587 features.
# Fitting estimator with 586 features.
# Fitting estimator with 585 features.
# Fitting estimator with 584 features.
# Fitting estimator with 583 features.
# Fitting estimator with 582 features.
# Fitting estimator with 581 features.
# Fitting estimator with 580 features.
# Fitting estimator with 579 features.
# Fitting estimator with 578 features.
# Fitting estimator with 577 features.
# Fitting estimator with 576 features.
# Fitting estimator with 575 features.
# Fitting estimator with 574 features.
# Fitting estimator with 573 features.
# Fitting estimator with 572 features.
# Fitting estimator with 571 features.
# Fitting estimator with 570 features.
# Fitting estimator with 569 features.
# Fitting estimator with 568 features.
# Fitting estimator with 567 features.
# Fitting estimator with 566 features.
# Fitting estimator with 565 features.
# Fitting estimator with 564 features.
# Fitting estimator with 563 features.
# Fitting estimator with 562 features.
# Fitting estimator with 561 features.
# Fitting estimator with 560 features.
# Fitting estimator with 559 features.
# Fitting estimator with 558 features.
# Fitting estimator with 557 features.
# Fitting estimator with 556 features.
# Fitting estimator with 555 features.
# Fitting estimator with 554 features.
# Fitting estimator with 553 features.
# Fitting estimator with 552 features.
# Fitting estimator with 551 features.
# Fitting estimator with 550 features.
# Fitting estimator with 549 features.
# Fitting estimator with 548 features.
# Fitting estimator with 547 features.
# Fitting estimator with 546 features.
# Fitting estimator with 545 features.
# Fitting estimator with 544 features.
# Fitting estimator with 543 features.
# Fitting estimator with 542 features.
# Fitting estimator with 541 features.
# Fitting estimator with 540 features.
# Fitting estimator with 539 features.
# Fitting estimator with 538 features.
# Fitting estimator with 537 features.
# Fitting estimator with 536 features.
# Fitting estimator with 535 features.
# Fitting estimator with 534 features.
# Fitting estimator with 533 features.
# Fitting estimator with 532 features.
# Fitting estimator with 531 features.
# Fitting estimator with 530 features.
# Fitting estimator with 529 features.
# Fitting estimator with 528 features.
# Fitting estimator with 527 features.
# Fitting estimator with 526 features.
# Fitting estimator with 525 features.
# Fitting estimator with 524 features.
# Fitting estimator with 523 features.
# Fitting estimator with 522 features.
# Fitting estimator with 521 features.
# Fitting estimator with 520 features.
# Fitting estimator with 519 features.

# %% [markdown]
# # 4. Linear Model Feature Ranking
#
# Now let's apply 3 different linear models (Linear, Lasso and Ridge Regression) and how the features are selected and prioritised via these models. To achieve this, I shall use the sklearn implementation of these models and in particular the attribute .coef to return the estimated coefficients for each feature in the linear model.

# %%
ranks
# Out:
# {'rlasso/Stability': {'feature_1': 0.0,
#   'feature_2': 0.0,
#   'feature_3': 0.0,
#   'elapsed_time': 0.0,
#   'agged_all_transactions_count': 0.0,
#   'agged_all_category_1_sum': 0.0,
#   'agged_all_category_1_mean': 0.0,
#   'agged_all_purchase_date_year_quarter_mean': 0.0,
#   'agged_all_purchase_date_year_quarter_median': 0.0,
#   'agged_all_city_id_modeplus': 0.0,
#   'agged_all_city_id_nunique': 0.0,
#   'agged_all_installments_sum': 0.0,
#   'agged_all_installments_mean': 0.0,
#   'agged_all_installments_max': 0.0,
#   'agged_all_installments_min': 0.0,
#   'agged_all_installments_std': 0.0,
#   'agged_all_installments_nunique': 0.0,
#   'agged_all_merchant_category_id_modeplus': 0.0,
#   'agged_all_merchant_category_id_nunique': 0.0,
#   'agged_all_month_lag_mean': 0.0,
#   'agged_all_month_lag_max': 0.0,
#   'agged_all_month_lag_min': 0.0,
#   'agged_all_month_lag_std': 0.0,
#   'agged_all_purchase_amount_sum': 0.0,
#   'agged_all_purchase_amount_mean': 0.0,
#   'agged_all_purchase_amount_max': 0.0,
#   'agged_all_purchase_amount_min': 0.0,
#   'agged_all_purchase_amount_std': 0.0,
#   'agged_all_state_id_modeplus': 0.0,
#   'agged_all_state_id_nunique': 0.0,
#   'agged_all_subsector_id_modeplus': 0.0,
#   'agged_all_subsector_id_nunique': 0.0,
#   'agged_all_no_city_mean': 0.0,
#   'agged_all_no_city_sum': 0.0,
#   'agged_all_undefined_installments_mean': 0.0,
#   'agged_all_undefined_installments_sum': 0.0,
#   'agged_all_undefined_installments_min': 0.0,
#   'agged_all_undefined_installments_max': 0.0,
#   'agged_all_big_installments_mean': 0.0,
#   'agged_all_big_installments_sum': 0.0,
#   'agged_all_big_installments_min': 0.0,
#   'agged_all_big_installments_max': 0.0,
#   'agged_all_cat2_dum_0.0_mean': 0.0,
#   'agged_all_cat2_dum_1.0_mean': 0.0,
#   'agged_all_cat2_dum_2.0_mean': 0.0,
#   'agged_all_cat2_dum_3.0_mean': 0.0,
#   'agged_all_cat2_dum_4.0_mean': 0.0,
#   'agged_all_cat2_dum_5.0_mean': 0.0,
#   'agged_all_cat2_dum_nan_mean': 0.0,
#   'agged_all_cat3_dum_A_mean': 0.0,
#   'agged_all_cat3_dum_B_mean': 0.0,
#   'agged_all_cat3_dum_C_mean': 0.0,
#   'agged_all_cat3_dum_nan_mean': 0.0,
#   'agged_all_purchase_date_all_weeks_ptp': 0.0,
#   'agged_all_purchase_date_all_weeks_min': 0.0,
#   'agged_all_purchase_date_all_weeks_mean': 0.0,
#   'agged_all_purchase_date_all_weeks_max': 0.0,
#   'agged_all_purchase_date_all_weeks_std': 0.0,
#   'agged_all_purchase_amount_unusual_mean': 0.0,
#   'agged_all_purchase_amount_unusual_sum': 0.0,
#   'agged_all_purchase_date_year_mean': 0.0,
#   'agged_all_purchase_date_year_max': 0.0,
#   'agged_all_purchase_date_year_min': 0.0,
#   'agged_all_purchase_date_season_mean': 0.0,
#   'agged_all_purchase_date_season_modeplus': 0.0,
#   'agged_all_purchase_date_season_std': 0.0,
#   'agged_all_purchase_date_activity_month_mean': 0.0,
#   'agged_all_purchase_date_activity_month_max': 0.0,
#   'agged_all_purchase_date_activity_month_min': 0.0,
#   'agged_all_purchase_date_activity_month_std': 0.0,
#   'agged_all_purchase_date_activity_month_ptp': 0.0,
#   'agged_all_purchase_date_month_mean': 0.0,
#   'agged_all_purchase_date_month_max': 0.0,
#   'agged_all_purchase_date_month_min': 0.0,
#   'agged_all_purchase_date_month_std': 0.0,
#   'agged_all_purchase_date_week_mean': 0.0,
#   'agged_all_purchase_date_week_max': 0.0,
#   'agged_all_purchase_date_week_min': 0.0,
#   'agged_all_purchase_date_week_std': 0.0,
#   'agged_all_purchase_date_months_week_mean': 0.0,
#   'agged_all_purchase_date_months_week_std': 0.0,
#   'agged_all_purchase_date_months_week_max': 0.0,
#   'agged_all_purchase_date_months_week_min': 0.0,
#   'agged_all_purchase_date_end_of_the_month_mean': 0.0,
#   'agged_all_purchase_years_day_mean': 0.0,
#   'agged_all_purchase_years_day_max': 0.0,
#   'agged_all_purchase_years_day_min': 0.0,
#   'agged_all_purchase_years_day_std': 0.0,
#   'agged_all_purchase_years_day_ptp': 0.0,
#   'agged_all_purchase_date_day_mean': 0.0,
#   'agged_all_purchase_date_day_std': 0.0,
#   'agged_all_purchase_date_day_max': 0.0,
#   'agged_all_purchase_date_day_min': 0.0,
#   'agged_all_purchase_date_weekend_mean': 0.0,
#   'agged_all_purchase_date_hour_mean': 0.0,
#   'agged_all_purchase_date_hour_std': 0.0,
#   'agged_all_purchase_date_hour_max': 0.0,
#   'agged_all_purchase_date_hour_min': 0.0,
#   'agged_all_purchase_date_day_cycle_mean': 0.0,
#   'agged_all_payment_per_month_sum': 0.0,
#   'agged_all_payment_per_month_mean': 0.0,
#   'agged_all_payment_per_month_std': 0.0,
#   'agged_all_number_of_purchases_max': 0.0,
#   'agged_all_valid_authorization_percent_max': 0.0,
#   'agged_all_payment_from_end_to_begging_mean': 0.0,
#   'agged_all_payment_from_end_to_begging_max': 0.0,
#   'agged_all_payment_from_end_to_begging_min': 0.0,
#   'agged_all_purchase_date_start_of_the_month_mean': 0.0,
#   'agged_all_position_from_start_to_finnish_mean': 0.0,
#   'agged_all_position_from_start_to_finnish_ptp': 0.0,
#   'agged_all_position_from_start_to_finnish_max': 0.0,
#   'agged_all_position_from_start_to_finnish_min': 0.0,
#   'agged_all_debt_until_month_mean': 0.0,
#   'agged_all_debt_until_month_std': 0.0,
#   'agged_all_debt_until_month_ptp': 0.0,
#   'eb_all_payment_from_end_to_begging_mean_PM': 0.0,
#   'eb_all_payment_from_end_to_begging_std_PM': 0.0,
#   'eb_all_purchase_amount_count_mean_PM': 0.0,
#   'eb_all_purchase_amount_count_std_PM': 0.0,
#   'eb_all_purchase_amount_sum_mean_PM': 0.0,
#   'eb_all_purchase_amount_sum_std_PM': 0.0,
#   'eb_all_purchase_amount_mean_mean_PM': 0.0,
#   'eb_all_purchase_amount_mean_std_PM': 0.0,
#   'eb_all_purchase_amount_median_mean_PM': 0.0,
#   'eb_all_purchase_amount_median_std_PM': 0.0,
#   'eb_all_purchase_amount_min_mean_PM': 0.0,
#   'eb_all_purchase_amount_min_std_PM': 0.0,
#   'eb_all_purchase_amount_max_mean_PM': 0.0,
#   'eb_all_purchase_amount_max_std_PM': 0.0,
#   'eb_all_purchase_amount_std_mean_PM': 0.0,
#   'eb_all_purchase_amount_std_std_PM': 0.0,
#   'eb_all_installments_count_mean_PM': 0.0,
#   'eb_all_installments_count_std_PM': 0.0,
#   'eb_all_installments_sum_mean_PM': 0.0,
#   'eb_all_installments_sum_std_PM': 0.0,
#   'eb_all_installments_mean_mean_PM': 0.0,
#   'eb_all_installments_mean_std_PM': 0.0,
#   'eb_all_installments_median_mean_PM': 0.0,
#   'eb_all_installments_median_std_PM': 0.0,
#   'eb_all_installments_min_mean_PM': 0.0,
#   'eb_all_installments_min_std_PM': 0.0,
#   'eb_all_installments_max_mean_PM': 0.0,
#   'eb_all_installments_max_std_PM': 0.0,
#   'eb_all_installments_std_mean_PM': 0.0,
#   'eb_all_installments_std_std_PM': 0.0,
#   'ml_all_month_lag_mean_PM': 0.0,
#   'ml_all_month_lag_std_PM': 0.0,
#   'ml_all_purchase_amount_count_mean_PM': 0.0,
#   'ml_all_purchase_amount_count_std_PM': 0.0,
#   'ml_all_purchase_amount_sum_mean_PM': 0.0,
#   'ml_all_purchase_amount_sum_std_PM': 0.0,
#   'ml_all_purchase_amount_mean_mean_PM': 0.0,
#   'ml_all_purchase_amount_mean_std_PM': 0.0,
#   'ml_all_purchase_amount_median_mean_PM': 0.0,
#   'ml_all_purchase_amount_median_std_PM': 0.0,
#   'ml_all_purchase_amount_min_mean_PM': 0.0,
#   'ml_all_purchase_amount_min_std_PM': 0.0,
#   'ml_all_purchase_amount_max_mean_PM': 0.0,
#   'ml_all_purchase_amount_max_std_PM': 0.0,
#   'ml_all_purchase_amount_std_mean_PM': 0.0,
#   'ml_all_purchase_amount_std_std_PM': 0.0,
#   'ml_all_installments_count_mean_PM': 0.0,
#   'ml_all_installments_count_std_PM': 0.0,
#   'ml_all_installments_sum_mean_PM': 0.0,
#   'ml_all_installments_sum_std_PM': 0.0,
#   'ml_all_installments_mean_mean_PM': 0.0,
#   'ml_all_installments_mean_std_PM': 0.0,
#   'ml_all_installments_median_mean_PM': 0.0,
#   'ml_all_installments_median_std_PM': 0.0,
#   'ml_all_installments_min_mean_PM': 0.0,
#   'ml_all_installments_min_std_PM': 0.0,
#   'ml_all_installments_max_mean_PM': 0.0,
#   'ml_all_installments_max_std_PM': 0.0,
#   'ml_all_installments_std_mean_PM': 0.0,
#   'ml_all_installments_std_std_PM': 0.0,
#   'eb_au_payment_from_end_to_begging_mean_PM': 0.0,
#   'eb_au_payment_from_end_to_begging_std_PM': 0.0,
#   'eb_au_purchase_amount_count_mean_PM': 0.0,
#   'eb_au_purchase_amount_count_std_PM': 0.0,
#   'eb_au_purchase_amount_sum_mean_PM': 0.0,
#   'eb_au_purchase_amount_sum_std_PM': 0.0,
#   'eb_au_purchase_amount_mean_mean_PM': 0.0,
#   'eb_au_purchase_amount_mean_std_PM': 0.0,
#   'eb_au_purchase_amount_median_mean_PM': 0.0,
#   'eb_au_purchase_amount_median_std_PM': 0.0,
#   'eb_au_purchase_amount_min_mean_PM': 0.0,
#   'eb_au_purchase_amount_min_std_PM': 0.0,
#   'eb_au_purchase_amount_max_mean_PM': 0.0,
#   'eb_au_purchase_amount_max_std_PM': 0.0,
#   'eb_au_purchase_amount_std_mean_PM': 0.0,
#   'eb_au_purchase_amount_std_std_PM': 0.0,
#   'eb_au_installments_count_mean_PM': 0.0,
#   'eb_au_installments_count_std_PM': 0.0,
#   'eb_au_installments_sum_mean_PM': 0.0,
#   'eb_au_installments_sum_std_PM': 0.0,
#   'eb_au_installments_mean_mean_PM': 0.0,
#   'eb_au_installments_mean_std_PM': 0.0,
#   'eb_au_installments_median_mean_PM': 0.0,
#   'eb_au_installments_median_std_PM': 0.0,
#   'eb_au_installments_min_mean_PM': 0.0,
#   'eb_au_installments_min_std_PM': 0.0,
#   'eb_au_installments_max_mean_PM': 0.0,
#   'eb_au_installments_max_std_PM': 0.0,
#   'eb_au_installments_std_mean_PM': 0.0,
#   'eb_au_installments_std_std_PM': 0.0,
#   'ml_au_month_lag_mean_PM': 0.0,
#   'ml_au_month_lag_std_PM': 0.0,
#   'ml_au_purchase_amount_count_mean_PM': 0.0,
#   'ml_au_purchase_amount_count_std_PM': 0.0,
#   'ml_au_purchase_amount_sum_mean_PM': 0.0,
#   'ml_au_purchase_amount_sum_std_PM': 0.0,
#   'ml_au_purchase_amount_mean_mean_PM': 0.0,
#   'ml_au_purchase_amount_mean_std_PM': 0.0,
#   'ml_au_purchase_amount_median_mean_PM': 0.0,
#   'ml_au_purchase_amount_median_std_PM': 0.0,
#   'ml_au_purchase_amount_min_mean_PM': 0.0,
#   'ml_au_purchase_amount_min_std_PM': 0.0,
#   'ml_au_purchase_amount_max_mean_PM': 0.0,
#   'ml_au_purchase_amount_max_std_PM': 0.0,
#   'ml_au_purchase_amount_std_mean_PM': 0.0,
#   'ml_au_purchase_amount_std_std_PM': 0.0,
#   'ml_au_installments_count_mean_PM': 0.0,
#   'ml_au_installments_count_std_PM': 0.0,
#   'ml_au_installments_sum_mean_PM': 0.0,
#   'ml_au_installments_sum_std_PM': 0.0,
#   'ml_au_installments_mean_mean_PM': 0.0,
#   'ml_au_installments_mean_std_PM': 0.0,
#   'ml_au_installments_median_mean_PM': 0.0,
#   'ml_au_installments_median_std_PM': 0.0,
#   'ml_au_installments_min_mean_PM': 0.0,
#   'ml_au_installments_min_std_PM': 0.0,
#   'ml_au_installments_max_mean_PM': 0.0,
#   'ml_au_installments_max_std_PM': 0.0,
#   'ml_au_installments_std_mean_PM': 0.0,
#   'ml_au_installments_std_std_PM': 0.0,
#   'eb_non_payment_from_end_to_begging_mean_PM': 0.0,
#   'eb_non_payment_from_end_to_begging_std_PM': 0.0,
#   'eb_non_purchase_amount_count_mean_PM': 0.0,
#   'eb_non_purchase_amount_count_std_PM': 0.0,
#   'eb_non_purchase_amount_sum_mean_PM': 0.0,
#   'eb_non_purchase_amount_sum_std_PM': 0.0,
#   'eb_non_purchase_amount_mean_mean_PM': 0.0,
#   'eb_non_purchase_amount_mean_std_PM': 0.0,
#   'eb_non_purchase_amount_median_mean_PM': 0.0,
#   'eb_non_purchase_amount_median_std_PM': 0.0,
#   'eb_non_purchase_amount_min_mean_PM': 0.0,
#   'eb_non_purchase_amount_min_std_PM': 0.0,
#   'eb_non_purchase_amount_max_mean_PM': 0.0,
#   'eb_non_purchase_amount_max_std_PM': 0.0,
#   'eb_non_purchase_amount_std_mean_PM': 0.0,
#   'eb_non_purchase_amount_std_std_PM': 0.0,
#   'eb_non_installments_count_mean_PM': 0.0,
#   'eb_non_installments_count_std_PM': 0.0,
#   'eb_non_installments_sum_mean_PM': 0.0,
#   'eb_non_installments_sum_std_PM': 0.0,
#   'eb_non_installments_mean_mean_PM': 0.0,
#   'eb_non_installments_mean_std_PM': 0.0,
#   'eb_non_installments_median_mean_PM': 0.0,
#   'eb_non_installments_median_std_PM': 0.0,
#   'eb_non_installments_min_mean_PM': 0.0,
#   'eb_non_installments_min_std_PM': 0.0,
#   'eb_non_installments_max_mean_PM': 0.0,
#   'eb_non_installments_max_std_PM': 0.0,
#   'eb_non_installments_std_mean_PM': 0.0,
#   'eb_non_installments_std_std_PM': 0.0,
#   'ml_non_month_lag_mean_PM': 0.0,
#   'ml_non_month_lag_std_PM': 0.0,
#   'ml_non_purchase_amount_count_mean_PM': 0.0,
#   'ml_non_purchase_amount_count_std_PM': 0.0,
#   'ml_non_purchase_amount_sum_mean_PM': 0.0,
#   'ml_non_purchase_amount_sum_std_PM': 0.0,
#   'ml_non_purchase_amount_mean_mean_PM': 0.0,
#   'ml_non_purchase_amount_mean_std_PM': 0.0,
#   'ml_non_purchase_amount_median_mean_PM': 0.0,
#   'ml_non_purchase_amount_median_std_PM': 0.0,
#   'ml_non_purchase_amount_min_mean_PM': 0.0,
#   'ml_non_purchase_amount_min_std_PM': 0.0,
#   'ml_non_purchase_amount_max_mean_PM': 0.0,
#   'ml_non_purchase_amount_max_std_PM': 0.0,
#   'ml_non_purchase_amount_std_mean_PM': 0.0,
#   'ml_non_purchase_amount_std_std_PM': 0.0,
#   'ml_non_installments_count_mean_PM': 0.0,
#   'ml_non_installments_count_std_PM': 0.0,
#   'ml_non_installments_sum_mean_PM': 0.0,
#   'ml_non_installments_sum_std_PM': 0.0,
#   'ml_non_installments_mean_mean_PM': 0.0,
#   'ml_non_installments_mean_std_PM': 0.0,
#   'ml_non_installments_median_mean_PM': 0.0,
#   'ml_non_installments_median_std_PM': 0.0,
#   'ml_non_installments_min_mean_PM': 0.0,
#   'ml_non_installments_min_std_PM': 0.0,
#   'ml_non_installments_max_mean_PM': 0.0,
#   'ml_non_installments_max_std_PM': 0.0,
#   'ml_non_installments_std_mean_PM': 0.0,
#   'ml_non_installments_std_std_PM': 0.0,
#   'category_1_purchase_amount_mean': 0.0,
#   'category_1_purchase_amount_min': 0.0,
#   'category_1_purchase_amount_max': 0.0,
#   'category_1_purchase_amount_std': 0.0,
#   'installments_purchase_amount_mean': 0.0,
#   'installments_purchase_amount_min': 0.0,
#   'installments_purchase_amount_max': 0.0,
#   'installments_purchase_amount_std': 0.0,
#   'city_id_purchase_amount_mean': 0.0,
#   'city_id_purchase_amount_min': 0.0,
#   'city_id_purchase_amount_max': 0.0,
#   'city_id_purchase_amount_std': 0.0,
#   'category_1_installments_mean': 0.0,
#   'category_1_installments_min': 0.0,
#   'category_1_installments_max': 0.0,
#   'category_1_installments_std': 0.0,
#   'agged_au_transactions_count': 0.0,
#   'agged_au_category_1_sum': 0.0,
#   'agged_au_category_1_mean': 0.0,
#   'agged_au_purchase_date_year_quarter_mean': 0.0,
#   'agged_au_purchase_date_year_quarter_median': 0.0,
#   'agged_au_city_id_modeplus': 0.0,
#   'agged_au_city_id_nunique': 0.0,
#   'agged_au_installments_sum': 0.0,
#   'agged_au_installments_mean': 0.0,
#   'agged_au_installments_max': 0.0,
#   'agged_au_installments_min': 0.0,
#   'agged_au_installments_std': 0.0,
#   'agged_au_installments_nunique': 0.0,
#   'agged_au_merchant_category_id_modeplus': 0.0,
#   'agged_au_merchant_category_id_nunique': 0.0,
#   'agged_au_month_lag_mean': 0.0,
#   'agged_au_month_lag_max': 0.0,
#   'agged_au_month_lag_min': 0.0,
#   'agged_au_month_lag_std': 0.0,
#   'agged_au_purchase_amount_sum': 0.0,
#   'agged_au_purchase_amount_mean': 0.0,
#   'agged_au_purchase_amount_max': 0.0,
#   'agged_au_purchase_amount_min': 0.0,
#   'agged_au_purchase_amount_std': 0.0,
#   'agged_au_state_id_modeplus': 0.0,
#   'agged_au_state_id_nunique': 0.0,
#   'agged_au_subsector_id_modeplus': 0.0,
#   'agged_au_subsector_id_nunique': 0.0,
#   'agged_au_no_city_mean': 0.0,
#   'agged_au_no_city_sum': 0.0,
#   'agged_au_undefined_installments_mean': 0.0,
#   'agged_au_undefined_installments_sum': 0.0,
#   'agged_au_undefined_installments_min': 0.0,
#   'agged_au_undefined_installments_max': 0.0,
#   'agged_au_big_installments_mean': 0.0,
#   'agged_au_big_installments_sum': 0.0,
#   'agged_au_big_installments_min': 0.0,
#   'agged_au_big_installments_max': 0.0,
#   'agged_au_cat2_dum_0.0_mean': 0.0,
#   'agged_au_cat2_dum_1.0_mean': 0.0,
#   'agged_au_cat2_dum_2.0_mean': 0.0,
#   'agged_au_cat2_dum_3.0_mean': 0.0,
#   'agged_au_cat2_dum_4.0_mean': 0.0,
#   'agged_au_cat2_dum_5.0_mean': 0.0,
#   'agged_au_cat2_dum_nan_mean': 0.0,
#   'agged_au_cat3_dum_A_mean': 0.0,
#   'agged_au_cat3_dum_B_mean': 0.0,
#   'agged_au_cat3_dum_C_mean': 0.0,
#   'agged_au_cat3_dum_nan_mean': 0.0,
#   'agged_au_purchase_date_all_weeks_ptp': 0.0,
#   'agged_au_purchase_date_all_weeks_min': 0.0,
#   'agged_au_purchase_date_all_weeks_mean': 0.0,
#   'agged_au_purchase_date_all_weeks_max': 0.0,
#   'agged_au_purchase_date_all_weeks_std': 0.0,
#   'agged_au_purchase_amount_unusual_mean': 0.0,
#   'agged_au_purchase_amount_unusual_sum': 0.0,
#   'agged_au_purchase_date_year_mean': 0.0,
#   'agged_au_purchase_date_year_max': 0.0,
#   'agged_au_purchase_date_year_min': 0.0,
#   'agged_au_purchase_date_season_mean': 0.0,
#   'agged_au_purchase_date_season_modeplus': 0.0,
#   'agged_au_purchase_date_season_std': 0.0,
#   'agged_au_purchase_date_activity_month_mean': 0.0,
#   'agged_au_purchase_date_activity_month_max': 0.0,
#   'agged_au_purchase_date_activity_month_min': 0.0,
#   'agged_au_purchase_date_activity_month_std': 0.0,
#   'agged_au_purchase_date_activity_month_ptp': 0.0,
#   'agged_au_purchase_date_month_mean': 0.0,
#   'agged_au_purchase_date_month_max': 0.0,
#   'agged_au_purchase_date_month_min': 0.0,
#   'agged_au_purchase_date_month_std': 0.0,
#   'agged_au_purchase_date_week_mean': 0.0,
#   'agged_au_purchase_date_week_max': 0.0,
#   'agged_au_purchase_date_week_min': 0.0,
#   'agged_au_purchase_date_week_std': 0.0,
#   'agged_au_purchase_date_months_week_mean': 0.0,
#   'agged_au_purchase_date_months_week_std': 0.0,
#   'agged_au_purchase_date_months_week_max': 0.0,
#   'agged_au_purchase_date_months_week_min': 0.0,
#   'agged_au_purchase_date_end_of_the_month_mean': 0.0,
#   'agged_au_purchase_years_day_mean': 0.0,
#   'agged_au_purchase_years_day_max': 0.0,
#   'agged_au_purchase_years_day_min': 0.0,
#   'agged_au_purchase_years_day_std': 0.0,
#   'agged_au_purchase_years_day_ptp': 0.0,
#   'agged_au_purchase_date_day_mean': 0.0,
#   'agged_au_purchase_date_day_std': 0.0,
#   'agged_au_purchase_date_day_max': 0.0,
#   'agged_au_purchase_date_day_min': 0.0,
#   'agged_au_purchase_date_weekend_mean': 0.0,
#   'agged_au_purchase_date_hour_mean': 0.0,
#   'agged_au_purchase_date_hour_std': 0.0,
#   'agged_au_purchase_date_hour_max': 0.0,
#   'agged_au_purchase_date_hour_min': 0.0,
#   'agged_au_purchase_date_day_cycle_mean': 0.0,
#   'agged_au_payment_per_month_sum': 0.0,
#   'agged_au_payment_per_month_mean': 0.0,
#   'agged_au_payment_per_month_std': 0.0,
#   'agged_au_number_of_purchases_max': 0.0,
#   'agged_au_valid_authorization_percent_max': 0.0,
#   'agged_au_payment_from_end_to_begging_mean': 0.0,
#   'agged_au_payment_from_end_to_begging_max': 0.0,
#   'agged_au_payment_from_end_to_begging_min': 0.0,
#   'agged_au_purchase_date_start_of_the_month_mean': 0.0,
#   'agged_au_position_from_start_to_finnish_mean': 0.0,
#   'agged_au_position_from_start_to_finnish_ptp': 0.0,
#   'agged_au_position_from_start_to_finnish_max': 0.0,
#   'agged_au_position_from_start_to_finnish_min': 0.0,
#   'agged_au_debt_until_month_mean': 0.0,
#   'agged_au_debt_until_month_std': 0.0,
#   'agged_au_debt_until_month_ptp': 0.0,
#   'agged_non_transactions_count': 0.0,
#   'agged_non_category_1_sum': 0.0,
#   'agged_non_category_1_mean': 0.0,
#   'agged_non_purchase_date_year_quarter_mean': 0.0,
#   'agged_non_purchase_date_year_quarter_median': 0.0,
#   'agged_non_city_id_modeplus': 0.0,
#   'agged_non_city_id_nunique': 0.0,
#   'agged_non_installments_sum': 0.0,
#   'agged_non_installments_mean': 0.0,
#   'agged_non_installments_max': 0.0,
#   'agged_non_installments_min': 0.0,
#   'agged_non_installments_std': 0.0,
#   'agged_non_installments_nunique': 0.0,
#   'agged_non_merchant_category_id_modeplus': 0.0,
#   'agged_non_merchant_category_id_nunique': 0.0,
#   'agged_non_month_lag_mean': 0.0,
#   'agged_non_month_lag_max': 0.0,
#   'agged_non_month_lag_min': 0.0,
#   'agged_non_month_lag_std': 0.0,
#   'agged_non_purchase_amount_sum': 0.0,
#   'agged_non_purchase_amount_mean': 0.0,
#   'agged_non_purchase_amount_max': 0.0,
#   'agged_non_purchase_amount_min': 0.0,
#   'agged_non_purchase_amount_std': 0.0,
#   'agged_non_state_id_modeplus': 0.0,
#   'agged_non_state_id_nunique': 0.0,
#   'agged_non_subsector_id_modeplus': 0.0,
#   'agged_non_subsector_id_nunique': 0.0,
#   'agged_non_no_city_mean': 0.0,
#   'agged_non_no_city_sum': 0.0,
#   'agged_non_undefined_installments_mean': 0.0,
#   'agged_non_undefined_installments_sum': 0.0,
#   'agged_non_undefined_installments_min': 0.0,
#   'agged_non_undefined_installments_max': 0.0,
#   'agged_non_big_installments_mean': 0.0,
#   'agged_non_big_installments_sum': 0.0,
#   'agged_non_big_installments_min': 0.0,
#   'agged_non_big_installments_max': 0.0,
#   'agged_non_cat2_dum_0.0_mean': 0.0,
#   'agged_non_cat2_dum_1.0_mean': 0.0,
#   'agged_non_cat2_dum_2.0_mean': 0.0,
#   'agged_non_cat2_dum_3.0_mean': 0.0,
#   'agged_non_cat2_dum_4.0_mean': 0.0,
#   'agged_non_cat2_dum_5.0_mean': 0.0,
#   'agged_non_cat2_dum_nan_mean': 0.0,
#   'agged_non_cat3_dum_A_mean': 0.0,
#   'agged_non_cat3_dum_B_mean': 0.0,
#   'agged_non_cat3_dum_C_mean': 0.0,
#   'agged_non_cat3_dum_nan_mean': 0.0,
#   'agged_non_purchase_date_all_weeks_ptp': 0.0,
#   'agged_non_purchase_date_all_weeks_min': 0.0,
#   'agged_non_purchase_date_all_weeks_mean': 0.0,
#   'agged_non_purchase_date_all_weeks_max': 0.0,
#   'agged_non_purchase_date_all_weeks_std': 0.0,
#   'agged_non_purchase_amount_unusual_mean': 0.0,
#   'agged_non_purchase_amount_unusual_sum': 0.0,
#   'agged_non_purchase_date_year_mean': 0.0,
#   'agged_non_purchase_date_year_max': 0.0,
#   'agged_non_purchase_date_year_min': 0.0,
#   'agged_non_purchase_date_season_mean': 0.0,
#   'agged_non_purchase_date_season_modeplus': 0.0,
#   'agged_non_purchase_date_season_std': 0.0,
#   'agged_non_purchase_date_activity_month_mean': 0.0,
#   'agged_non_purchase_date_activity_month_max': 0.0,
#   'agged_non_purchase_date_activity_month_min': 0.0,
#   'agged_non_purchase_date_activity_month_std': 0.0,
#   'agged_non_purchase_date_activity_month_ptp': 0.0,
#   'agged_non_purchase_date_month_mean': 0.0,
#   'agged_non_purchase_date_month_max': 0.0,
#   'agged_non_purchase_date_month_min': 0.0,
#   'agged_non_purchase_date_month_std': 0.0,
#   'agged_non_purchase_date_week_mean': 0.0,
#   'agged_non_purchase_date_week_max': 0.0,
#   'agged_non_purchase_date_week_min': 0.0,
#   'agged_non_purchase_date_week_std': 0.0,
#   'agged_non_purchase_date_months_week_mean': 0.0,
#   'agged_non_purchase_date_months_week_std': 0.0,
#   'agged_non_purchase_date_months_week_max': 0.0,
#   'agged_non_purchase_date_months_week_min': 0.0,
#   'agged_non_purchase_date_end_of_the_month_mean': 0.0,
#   'agged_non_purchase_years_day_mean': 0.0,
#   'agged_non_purchase_years_day_max': 0.0,
#   'agged_non_purchase_years_day_min': 0.0,
#   'agged_non_purchase_years_day_std': 0.0,
#   'agged_non_purchase_years_day_ptp': 0.0,
#   'agged_non_purchase_date_day_mean': 0.0,
#   'agged_non_purchase_date_day_std': 0.0,
#   'agged_non_purchase_date_day_max': 0.0,
#   'agged_non_purchase_date_day_min': 0.0,
#   'agged_non_purchase_date_weekend_mean': 0.0,
#   'agged_non_purchase_date_hour_mean': 0.0,
#   'agged_non_purchase_date_hour_std': 0.0,
#   'agged_non_purchase_date_hour_max': 0.0,
#   'agged_non_purchase_date_hour_min': 0.0,
#   'agged_non_purchase_date_day_cycle_mean': 0.0,
#   'agged_non_payment_per_month_sum': 0.0,
#   'agged_non_payment_per_month_mean': 0.0,
#   'agged_non_payment_per_month_std': 0.0,
#   'agged_non_number_of_purchases_max': 0.0,
#   'agged_non_valid_authorization_percent_max': 0.0,
#   'agged_non_payment_from_end_to_begging_mean': 0.0,
#   'agged_non_payment_from_end_to_begging_max': 0.0,
#   'agged_non_payment_from_end_to_begging_min': 0.0,
#   'agged_non_purchase_date_start_of_the_month_mean': 0.0,
#   'agged_non_position_from_start_to_finnish_mean': 0.0,
#   'agged_non_position_from_start_to_finnish_ptp': 0.0,
#   'agged_non_position_from_start_to_finnish_max': 0.0,
#   'agged_non_position_from_start_to_finnish_min': 0.0,
#   'agged_non_debt_until_month_mean': 0.0,
#   'agged_non_debt_until_month_std': 0.0,
#   'agged_non_debt_until_month_ptp': 0.0,
#   '0to1_rel_gen_mean': 0.0,
#   '1to2_rel_gen_mean': 0.0,
#   '2to3_rel_gen_mean': 0.0,
#   '3to4_rel_gen_mean': 0.0,
#   '4to5_rel_gen_mean': 0.0,
#   '5to6_rel_gen_mean': 0.0,
#   '6to7_rel_gen_mean': 0.0,
#   '7to8_rel_gen_mean': 0.0,
#   '8to9_rel_gen_mean': 0.0,
#   '9to10_rel_gen_mean': 0.0,
#   '10to11_rel_gen_mean': 0.0,
#   '11to12_rel_gen_mean': 0.0,
#   '12to13_rel_gen_mean': 0.0,
#   '13to14_rel_gen_mean': 0.0,
#   '14to15_rel_gen_mean': 0.0,
#   '0to1_rel_mean': 0.0,
#   '1to2_rel_mean': 0.0,
#   '2to3_rel_mean': 0.0,
#   '3to4_rel_mean': 0.0,
#   '4to5_rel_mean': 0.0,
#   '5to6_rel_mean': 0.0,
#   '6to7_rel_mean': 0.0,
#   '7to8_rel_mean': 0.0,
#   '8to9_rel_mean': 0.0,
#   '9to10_rel_mean': 0.0,
#   '10to11_rel_mean': 0.0,
#   '11to12_rel_mean': 0.0,
#   '12to13_rel_mean': 0.0,
#   '13to14_rel_mean': 0.0,
#   '14to15_rel_mean': 0.0,
#   'transactions_count': 0.0,
#   '0th_month_debt_bte_sum': 0.0,
#   '0th_month_debt_bte_mean': 0.0,
#   '0th_month_debt_bte_std': 0.0,
#   '1th_month_debt_bte_sum': 0.0,
#   '1th_month_debt_bte_mean': 0.0,
#   '1th_month_debt_bte_std': 0.0,
#   '2th_month_debt_bte_sum': 0.0,
#   '2th_month_debt_bte_mean': 0.0,
#   '2th_month_debt_bte_std': 0.0,
#   '3th_month_debt_bte_sum': 0.0,
#   '3th_month_debt_bte_mean': 0.0,
#   '3th_month_debt_bte_std': 0.0,
#   '4th_month_debt_bte_sum': 0.0,
#   '4th_month_debt_bte_mean': 0.0,
#   '4th_month_debt_bte_std': 0.0,
#   '5th_month_debt_bte_sum': 0.0,
#   '5th_month_debt_bte_mean': 0.0,
#   '5th_month_debt_bte_std': 0.0,
#   '6th_month_debt_bte_sum': 0.0,
#   '6th_month_debt_bte_mean': 0.0,
#   '6th_month_debt_bte_std': 0.0,
#   '7th_month_debt_bte_sum': 0.0,
#   '7th_month_debt_bte_mean': 0.0,
#   '7th_month_debt_bte_std': 0.0,
#   '8th_month_debt_bte_sum': 0.0,
#   '8th_month_debt_bte_mean': 0.0,
#   '8th_month_debt_bte_std': 0.0,
#   '9th_month_debt_bte_sum': 0.0,
#   '9th_month_debt_bte_mean': 0.0,
#   '9th_month_debt_bte_std': 0.0,
#   '10th_month_debt_bte_sum': 0.0,
#   '10th_month_debt_bte_mean': 0.0,
#   '10th_month_debt_bte_std': 0.0,
#   '11th_month_debt_bte_sum': 0.0,
#   '11th_month_debt_bte_mean': 0.0,
#   '11th_month_debt_bte_std': 0.0,
#   '12th_month_debt_bte_sum': 0.0,
#   '12th_month_debt_bte_mean': 0.0,
#   '12th_month_debt_bte_std': 0.0,
#   '13th_month_debt_bte_sum': 0.0,
#   '13th_month_debt_bte_mean': 0.0,
#   '13th_month_debt_bte_std': 0.0,
#   '14th_month_debt_bte_sum': 0.0,
#   '14th_month_debt_bte_mean': 0.0,
#   '14th_month_debt_bte_std': 0.0,
#   '15th_month_debt_bte_sum': 0.0,
#   '15th_month_debt_bte_mean': 0.0,
#   '15th_month_debt_bte_std': 0.0,
#   '16th_month_debt_bte_sum': 0.0,
#   '16th_month_debt_bte_mean': 0.0,
#   '16th_month_debt_bte_std': 0.0,
#   '17th_month_debt_bte_sum': 0.0,
#   '17th_month_debt_bte_mean': 0.0,
#   '17th_month_debt_bte_std': 0.0,
#   '18th_month_debt_bte_sum': 0.0,
#   '18th_month_debt_bte_mean': 0.0,
#   '18th_month_debt_bte_std': 0.0,
#   '19th_month_debt_bte_sum': 0.0,
#   '19th_month_debt_bte_mean': 0.0,
#   '19th_month_debt_bte_std': 0.0,
#   '20th_month_debt_bte_sum': 0.0,
#   '20th_month_debt_bte_mean': 0.0,
#   '20th_month_debt_bte_std': 0.0,
#   '21th_month_debt_bte_sum': 0.0,
#   '21th_month_debt_bte_mean': 0.0,
#   '21th_month_debt_bte_std': 0.0,
#   '22th_month_debt_bte_sum': 0.0,
#   '22th_month_debt_bte_mean': 0.0,
#   '22th_month_debt_bte_std': 0.0,
#   '23th_month_debt_bte_sum': 0.0,
#   '23th_month_debt_bte_mean': 0.0,
#   '23th_month_debt_bte_std': 0.0,
#   '24th_month_debt_bte_sum': 0.0,
#   '24th_month_debt_bte_mean': 0.0,
#   '24th_month_debt_bte_std': 0.0,
#   '25th_month_debt_bte_sum': 0.0,
#   '25th_month_debt_bte_mean': 0.0,
#   '25th_month_debt_bte_std': 0.0,
#   '26th_month_debt_bte_sum': 0.0,
#   '26th_month_debt_bte_mean': 0.0,
#   '26th_month_debt_bte_std': 0.0,
#   '27th_month_debt_bte_sum': 0.0,
#   '27th_month_debt_bte_mean': 0.0,
#   '27th_month_debt_bte_std': 0.0,
#   '28th_month_debt_bte_sum': 0.0,
#   '28th_month_debt_bte_mean': 0.0,
#   '28th_month_debt_bte_std': 0.0,
#   'last_purchase_month_bins': 0.0,
#   'feature_1_pr': 0.0,
#   'feature_2_pr': 0.0,
#   'feature_3_pr': 0.0},
#  'RFE': {'feature_1': 0.29,
#   'feature_2': 0.31,
#   'feature_3': 0.96,
#   'elapsed_time': 0.06,
#   'agged_all_transactions_count': 0.56,
#   'agged_all_category_1_sum': 0.85,
#   'agged_all_category_1_mean': 0.42,
#   'agged_all_purchase_date_year_quarter_mean': 0.97,
#   'agged_all_purchase_date_year_quarter_median': 0.09,
#   'agged_all_city_id_modeplus': 0.16,
#   'agged_all_city_id_nunique': 0.21,
#   'agged_all_installments_sum': 0.8,
#   'agged_all_installments_mean': 0.94,
#   'agged_all_installments_max': 0.24,
#   'agged_all_installments_min': 0.39,
#   'agged_all_installments_std': 0.33,
#   'agged_all_installments_nunique': 0.24,
#   'agged_all_merchant_category_id_modeplus': 0.19,
#   'agged_all_merchant_category_id_nunique': 0.26,
#   'agged_all_month_lag_mean': 0.72,
#   'agged_all_month_lag_max': 0.93,
#   'agged_all_month_lag_min': 0.89,
#   'agged_all_month_lag_std': 0.83,
#   'agged_all_purchase_amount_sum': 0.45,
#   'agged_all_purchase_amount_mean': 0.03,
#   'agged_all_purchase_amount_max': 0.04,
#   'agged_all_purchase_amount_min': 0.37,
#   'agged_all_purchase_amount_std': 0.04,
#   'agged_all_state_id_modeplus': 0.31,
#   'agged_all_state_id_nunique': 0.38,
#   'agged_all_subsector_id_modeplus': 0.28,
#   'agged_all_subsector_id_nunique': 0.26,
#   'agged_all_no_city_mean': 0.44,
#   'agged_all_no_city_sum': 0.87,
#   'agged_all_undefined_installments_mean': 0.98,
#   'agged_all_undefined_installments_sum': 0.86,
#   'agged_all_undefined_installments_min': 0.98,
#   'agged_all_undefined_installments_max': 0.35,
#   'agged_all_big_installments_mean': 0.44,
#   'agged_all_big_installments_sum': 0.99,
#   'agged_all_big_installments_min': 0.99,
#   'agged_all_big_installments_max': 1.0,
#   'agged_all_cat2_dum_0.0_mean': 0.97,
#   'agged_all_cat2_dum_1.0_mean': 0.98,
#   'agged_all_cat2_dum_2.0_mean': 0.98,
#   'agged_all_cat2_dum_3.0_mean': 0.98,
#   'agged_all_cat2_dum_4.0_mean': 0.97,
#   'agged_all_cat2_dum_5.0_mean': 0.98,
#   'agged_all_cat2_dum_nan_mean': 0.97,
#   'agged_all_cat3_dum_A_mean': 0.99,
#   'agged_all_cat3_dum_B_mean': 0.99,
#   'agged_all_cat3_dum_C_mean': 0.98,
#   'agged_all_cat3_dum_nan_mean': 0.99,
#   'agged_all_purchase_date_all_weeks_ptp': 0.65,
#   'agged_all_purchase_date_all_weeks_min': 0.65,
#   'agged_all_purchase_date_all_weeks_mean': 0.89,
#   'agged_all_purchase_date_all_weeks_max': 0.65,
#   'agged_all_purchase_date_all_weeks_std': 0.29,
#   'agged_all_purchase_amount_unusual_mean': 0.43,
#   'agged_all_purchase_amount_unusual_sum': 0.73,
#   'agged_all_purchase_date_year_mean': 0.97,
#   'agged_all_purchase_date_year_max': 0.43,
#   'agged_all_purchase_date_year_min': 0.93,
#   'agged_all_purchase_date_season_mean': 0.97,
#   'agged_all_purchase_date_season_modeplus': 0.24,
#   'agged_all_purchase_date_season_std': 0.42,
#   'agged_all_purchase_date_activity_month_mean': 0.84,
#   'agged_all_purchase_date_activity_month_max': 0.93,
#   'agged_all_purchase_date_activity_month_min': 0.91,
#   'agged_all_purchase_date_activity_month_std': 0.82,
#   'agged_all_purchase_date_activity_month_ptp': 0.75,
#   'agged_all_purchase_date_month_mean': 0.92,
#   'agged_all_purchase_date_month_max': 0.41,
#   'agged_all_purchase_date_month_min': 0.39,
#   'agged_all_purchase_date_month_std': 0.42,
#   'agged_all_purchase_date_week_mean': 0.89,
#   'agged_all_purchase_date_week_max': 0.3,
#   'agged_all_purchase_date_week_min': 0.39,
#   'agged_all_purchase_date_week_std': 0.31,
#   'agged_all_purchase_date_months_week_mean': 0.43,
#   'agged_all_purchase_date_months_week_std': 0.31,
#   'agged_all_purchase_date_months_week_max': 0.36,
#   'agged_all_purchase_date_months_week_min': 0.22,
#   'agged_all_purchase_date_end_of_the_month_mean': 0.4,
#   'agged_all_purchase_years_day_mean': 0.6,
#   'agged_all_purchase_years_day_max': 0.63,
#   'agged_all_purchase_years_day_min': 0.63,
#   'agged_all_purchase_years_day_std': 0.29,
#   'agged_all_purchase_years_day_ptp': 0.63,
#   'agged_all_purchase_date_day_mean': 0.6,
#   'agged_all_purchase_date_day_std': 0.29,
#   'agged_all_purchase_date_day_max': 0.18,
#   'agged_all_purchase_date_day_min': 0.17,
#   'agged_all_purchase_date_weekend_mean': 0.28,
#   'agged_all_purchase_date_hour_mean': 0.32,
#   'agged_all_purchase_date_hour_std': 0.27,
#   'agged_all_purchase_date_hour_max': 0.17,
#   'agged_all_purchase_date_hour_min': 0.23,
#   'agged_all_purchase_date_day_cycle_mean': 0.33,
#   'agged_all_payment_per_month_sum': 0.49,
#   'agged_all_payment_per_month_mean': 0.11,
#   'agged_all_payment_per_month_std': 0.07,
#   'agged_all_number_of_purchases_max': 0.56,
#   'agged_all_valid_authorization_percent_max': 0.92,
#   'agged_all_payment_from_end_to_begging_mean': 0.94,
#   'agged_all_payment_from_end_to_begging_max': 0.91,
#   'agged_all_payment_from_end_to_begging_min': 0.95,
#   'agged_all_purchase_date_start_of_the_month_mean': 0.39,
#   'agged_all_position_from_start_to_finnish_mean': 0.87,
#   'agged_all_position_from_start_to_finnish_ptp': 0.89,
#   'agged_all_position_from_start_to_finnish_max': 0.94,
#   'agged_all_position_from_start_to_finnish_min': 0.9,
#   'agged_all_debt_until_month_mean': 0.94,
#   'agged_all_debt_until_month_std': 0.28,
#   'agged_all_debt_until_month_ptp': 0.28,
#   'eb_all_payment_from_end_to_begging_mean_PM': 0.83,
#   'eb_all_payment_from_end_to_begging_std_PM': 0.67,
#   'eb_all_purchase_amount_count_mean_PM': 0.64,
#   'eb_all_purchase_amount_count_std_PM': 0.68,
#   'eb_all_purchase_amount_sum_mean_PM': 0.48,
#   'eb_all_purchase_amount_sum_std_PM': 0.48,
#   'eb_all_purchase_amount_mean_mean_PM': 0.48,
#   'eb_all_purchase_amount_mean_std_PM': 0.5,
#   'eb_all_purchase_amount_median_mean_PM': 0.53,
#   'eb_all_purchase_amount_median_std_PM': 0.52,
#   'eb_all_purchase_amount_min_mean_PM': 0.65,
#   'eb_all_purchase_amount_min_std_PM': 0.59,
#   'eb_all_purchase_amount_max_mean_PM': 0.5,
#   'eb_all_purchase_amount_max_std_PM': 0.49,
#   'eb_all_purchase_amount_std_mean_PM': 0.51,
#   'eb_all_purchase_amount_std_std_PM': 0.51,
#   'eb_all_installments_count_mean_PM': 0.62,
#   'eb_all_installments_count_std_PM': 0.65,
#   'eb_all_installments_sum_mean_PM': 0.57,
#   'eb_all_installments_sum_std_PM': 0.66,
#   'eb_all_installments_mean_mean_PM': 0.76,
#   'eb_all_installments_mean_std_PM': 0.88,
#   'eb_all_installments_median_mean_PM': 0.83,
#   'eb_all_installments_median_std_PM': 0.62,
#   'eb_all_installments_min_mean_PM': 0.89,
#   'eb_all_installments_min_std_PM': 0.74,
#   'eb_all_installments_max_mean_PM': 0.79,
#   'eb_all_installments_max_std_PM': 0.69,
#   'eb_all_installments_std_mean_PM': 0.86,
#   'eb_all_installments_std_std_PM': 0.71,
#   'ml_all_month_lag_mean_PM': 0.83,
#   'ml_all_month_lag_std_PM': 0.68,
#   'ml_all_purchase_amount_count_mean_PM': 0.61,
#   'ml_all_purchase_amount_count_std_PM': 0.63,
#   'ml_all_purchase_amount_sum_mean_PM': 0.48,
#   'ml_all_purchase_amount_sum_std_PM': 0.48,
#   'ml_all_purchase_amount_mean_mean_PM': 0.47,
#   'ml_all_purchase_amount_mean_std_PM': 0.5,
#   'ml_all_purchase_amount_median_mean_PM': 0.53,
#   'ml_all_purchase_amount_median_std_PM': 0.52,
#   'ml_all_purchase_amount_min_mean_PM': 0.65,
#   'ml_all_purchase_amount_min_std_PM': 0.59,
#   'ml_all_purchase_amount_max_mean_PM': 0.49,
#   'ml_all_purchase_amount_max_std_PM': 0.49,
#   'ml_all_purchase_amount_std_mean_PM': 0.52,
#   'ml_all_purchase_amount_std_std_PM': 0.51,
#   'ml_all_installments_count_mean_PM': 0.64,
#   'ml_all_installments_count_std_PM': 0.68,
#   'ml_all_installments_sum_mean_PM': 0.57,
#   'ml_all_installments_sum_std_PM': 0.66,
#   'ml_all_installments_mean_mean_PM': 0.75,
#   'ml_all_installments_mean_std_PM': 0.88,
#   'ml_all_installments_median_mean_PM': 0.83,
#   'ml_all_installments_median_std_PM': 0.62,
#   'ml_all_installments_min_mean_PM': 0.89,
#   'ml_all_installments_min_std_PM': 0.74,
#   'ml_all_installments_max_mean_PM': 0.79,
#   'ml_all_installments_max_std_PM': 0.69,
#   'ml_all_installments_std_mean_PM': 0.86,
#   'ml_all_installments_std_std_PM': 0.71,
#   'eb_au_payment_from_end_to_begging_mean_PM': 0.91,
#   'eb_au_payment_from_end_to_begging_std_PM': 0.76,
#   'eb_au_purchase_amount_count_mean_PM': 0.62,
#   'eb_au_purchase_amount_count_std_PM': 0.59,
#   'eb_au_purchase_amount_sum_mean_PM': 0.54,
#   'eb_au_purchase_amount_sum_std_PM': 0.54,
#   'eb_au_purchase_amount_mean_mean_PM': 0.77,
#   'eb_au_purchase_amount_mean_std_PM': 0.62,
#   'eb_au_purchase_amount_median_mean_PM': 0.78,
#   'eb_au_purchase_amount_median_std_PM': 0.57,
#   'eb_au_purchase_amount_min_mean_PM': 0.6,
#   'eb_au_purchase_amount_min_std_PM': 0.72,
#   'eb_au_purchase_amount_max_mean_PM': 0.79,
#   'eb_au_purchase_amount_max_std_PM': 0.63,
#   'eb_au_purchase_amount_std_mean_PM': 0.75,
#   'eb_au_purchase_amount_std_std_PM': 0.73,
#   'eb_au_installments_count_mean_PM': 0.68,
#   'eb_au_installments_count_std_PM': 0.58,
#   'eb_au_installments_sum_mean_PM': 0.69,
#   'eb_au_installments_sum_std_PM': 0.7,
#   'eb_au_installments_mean_mean_PM': 0.88,
#   'eb_au_installments_mean_std_PM': 0.9,
#   'eb_au_installments_median_mean_PM': 0.55,
#   'eb_au_installments_median_std_PM': 0.69,
#   'eb_au_installments_min_mean_PM': 0.82,
#   'eb_au_installments_min_std_PM': 0.86,
#   'eb_au_installments_max_mean_PM': 0.72,
#   'eb_au_installments_max_std_PM': 0.76,
#   'eb_au_installments_std_mean_PM': 0.83,
#   'eb_au_installments_std_std_PM': 0.9,
#   'ml_au_month_lag_mean_PM': 0.9,
#   'ml_au_month_lag_std_PM': 0.76,
#   'ml_au_purchase_amount_count_mean_PM': 0.68,
#   'ml_au_purchase_amount_count_std_PM': 0.59,
#   'ml_au_purchase_amount_sum_mean_PM': 0.54,
#   'ml_au_purchase_amount_sum_std_PM': 0.54,
#   'ml_au_purchase_amount_mean_mean_PM': 0.77,
#   'ml_au_purchase_amount_mean_std_PM': 0.62,
#   'ml_au_purchase_amount_median_mean_PM': 0.78,
#   'ml_au_purchase_amount_median_std_PM': 0.57,
#   'ml_au_purchase_amount_min_mean_PM': 0.6,
#   'ml_au_purchase_amount_min_std_PM': 0.72,
#   'ml_au_purchase_amount_max_mean_PM': 0.79,
#   'ml_au_purchase_amount_max_std_PM': 0.63,
#   'ml_au_purchase_amount_std_mean_PM': 0.75,
#   'ml_au_purchase_amount_std_std_PM': 0.72,
#   'ml_au_installments_count_mean_PM': 0.55,
#   'ml_au_installments_count_std_PM': 0.58,
#   'ml_au_installments_sum_mean_PM': 0.69,
#   'ml_au_installments_sum_std_PM': 0.7,
#   'ml_au_installments_mean_mean_PM': 0.88,
#   'ml_au_installments_mean_std_PM': 0.9,
#   'ml_au_installments_median_mean_PM': 0.54,
#   'ml_au_installments_median_std_PM': 0.68,
#   'ml_au_installments_min_mean_PM': 0.82,
#   'ml_au_installments_min_std_PM': 0.85,
#   'ml_au_installments_max_mean_PM': 0.72,
#   'ml_au_installments_max_std_PM': 0.76,
#   'ml_au_installments_std_mean_PM': 0.84,
#   'ml_au_installments_std_std_PM': 0.9,
#   'eb_non_payment_from_end_to_begging_mean_PM': 0.84,
#   'eb_non_payment_from_end_to_begging_std_PM': 0.71,
#   'eb_non_purchase_amount_count_mean_PM': 0.73,
#   'eb_non_purchase_amount_count_std_PM': 0.77,
#   'eb_non_purchase_amount_sum_mean_PM': 0.46,
#   'eb_non_purchase_amount_sum_std_PM': 0.53,
#   'eb_non_purchase_amount_mean_mean_PM': 0.47,
#   'eb_non_purchase_amount_mean_std_PM': 0.5,
#   'eb_non_purchase_amount_median_mean_PM': 0.46,
#   'eb_non_purchase_amount_median_std_PM': 0.52,
#   'eb_non_purchase_amount_min_mean_PM': 0.47,
#   'eb_non_purchase_amount_min_std_PM': 0.48,
#   'eb_non_purchase_amount_max_mean_PM': 0.46,
#   'eb_non_purchase_amount_max_std_PM': 0.5,
#   'eb_non_purchase_amount_std_mean_PM': 0.53,
#   'eb_non_purchase_amount_std_std_PM': 0.52,
#   'eb_non_installments_count_mean_PM': 0.7,
#   'eb_non_installments_count_std_PM': 0.77,
#   'eb_non_installments_sum_mean_PM': 0.64,
#   'eb_non_installments_sum_std_PM': 0.59,
#   'eb_non_installments_mean_mean_PM': 0.67,
#   'eb_non_installments_mean_std_PM': 0.55,
#   'eb_non_installments_median_mean_PM': 0.64,
#   'eb_non_installments_median_std_PM': 0.58,
#   'eb_non_installments_min_mean_PM': 0.6,
#   'eb_non_installments_min_std_PM': 0.6,
#   'eb_non_installments_max_mean_PM': 0.56,
#   'eb_non_installments_max_std_PM': 0.61,
#   'eb_non_installments_std_mean_PM': 0.56,
#   'eb_non_installments_std_std_PM': 0.79,
#   'ml_non_month_lag_mean_PM': 0.85,
#   'ml_non_month_lag_std_PM': 0.71,
#   'ml_non_purchase_amount_count_mean_PM': 0.71,
#   'ml_non_purchase_amount_count_std_PM': 0.69,
#   'ml_non_purchase_amount_sum_mean_PM': 0.46,
#   'ml_non_purchase_amount_sum_std_PM': 0.53,
#   'ml_non_purchase_amount_mean_mean_PM': 0.47,
#   'ml_non_purchase_amount_mean_std_PM': 0.5,
#   'ml_non_purchase_amount_median_mean_PM': 0.46,
#   'ml_non_purchase_amount_median_std_PM': 0.52,
#   'ml_non_purchase_amount_min_mean_PM': 0.47,
#   'ml_non_purchase_amount_min_std_PM': 0.48,
#   'ml_non_purchase_amount_max_mean_PM': 0.46,
#   'ml_non_purchase_amount_max_std_PM': 0.5,
#   'ml_non_purchase_amount_std_mean_PM': 0.53,
#   'ml_non_purchase_amount_std_std_PM': 0.52,
#   'ml_non_installments_count_mean_PM': 0.73,
#   'ml_non_installments_count_std_PM': 0.7,
#   'ml_non_installments_sum_mean_PM': 0.64,
#   'ml_non_installments_sum_std_PM': 0.58,
#   'ml_non_installments_mean_mean_PM': 0.67,
#   'ml_non_installments_mean_std_PM': 0.55,
#   'ml_non_installments_median_mean_PM': 0.64,
#   'ml_non_installments_median_std_PM': 0.58,
#   'ml_non_installments_min_mean_PM': 0.61,
#   'ml_non_installments_min_std_PM': 0.59,
#   'ml_non_installments_max_mean_PM': 0.56,
#   'ml_non_installments_max_std_PM': 0.61,
#   'ml_non_installments_std_mean_PM': 0.56,
#   'ml_non_installments_std_std_PM': 0.79,
#   'category_1_purchase_amount_mean': 0.51,
#   'category_1_purchase_amount_min': 0.51,
#   'category_1_purchase_amount_max': 0.47,
#   'category_1_purchase_amount_std': 0.51,
#   'installments_purchase_amount_mean': 0.09,
#   'installments_purchase_amount_min': 0.1,
#   'installments_purchase_amount_max': 0.08,
#   'installments_purchase_amount_std': 0.09,
#   'city_id_purchase_amount_mean': 0.05,
#   'city_id_purchase_amount_min': 0.08,
#   'city_id_purchase_amount_max': 0.01,
#   'city_id_purchase_amount_std': 0.05,
#   'category_1_installments_mean': 0.84,
#   'category_1_installments_min': 0.84,
#   'category_1_installments_max': 0.74,
#   'category_1_installments_std': 0.84,
#   'agged_au_transactions_count': 0.56,
#   'agged_au_category_1_sum': 0.85,
#   'agged_au_category_1_mean': 0.3,
#   'agged_au_purchase_date_year_quarter_mean': 0.96,
#   'agged_au_purchase_date_year_quarter_median': 0.31,
#   'agged_au_city_id_modeplus': 0.16,
#   'agged_au_city_id_nunique': 0.2,
#   'agged_au_installments_sum': 0.8,
#   'agged_au_installments_mean': 0.91,
#   'agged_au_installments_max': 0.21,
#   'agged_au_installments_min': 0.26,
#   'agged_au_installments_std': 0.33,
#   'agged_au_installments_nunique': 0.19,
#   'agged_au_merchant_category_id_modeplus': 0.21,
#   'agged_au_merchant_category_id_nunique': 0.32,
#   'agged_au_month_lag_mean': 0.72,
#   'agged_au_month_lag_max': 0.96,
#   'agged_au_month_lag_min': 0.7,
#   'agged_au_month_lag_std': 0.65,
#   'agged_au_purchase_amount_sum': 0.45,
#   'agged_au_purchase_amount_mean': 0.13,
#   'agged_au_purchase_amount_max': 0.14,
#   'agged_au_purchase_amount_min': 0.37,
#   'agged_au_purchase_amount_std': 0.14,
#   'agged_au_state_id_modeplus': 0.28,
#   'agged_au_state_id_nunique': 0.38,
#   'agged_au_subsector_id_modeplus': 0.21,
#   'agged_au_subsector_id_nunique': 0.26,
#   'agged_au_no_city_mean': 0.44,
#   'agged_au_no_city_sum': 0.87,
#   'agged_au_undefined_installments_mean': 0.93,
#   'agged_au_undefined_installments_sum': 0.86,
#   'agged_au_undefined_installments_min': 0.26,
#   'agged_au_undefined_installments_max': 0.35,
#   'agged_au_big_installments_mean': 0.45,
#   'agged_au_big_installments_sum': 1.0,
#   'agged_au_big_installments_min': 0.26,
#   'agged_au_big_installments_max': 1.0,
#   'agged_au_cat2_dum_0.0_mean': 0.95,
#   'agged_au_cat2_dum_1.0_mean': 0.95,
#   'agged_au_cat2_dum_2.0_mean': 0.95,
#   'agged_au_cat2_dum_3.0_mean': 0.94,
#   'agged_au_cat2_dum_4.0_mean': 0.95,
#   'agged_au_cat2_dum_5.0_mean': 0.95,
#   'agged_au_cat2_dum_nan_mean': 0.23,
#   'agged_au_cat3_dum_A_mean': 0.91,
#   'agged_au_cat3_dum_B_mean': 0.91,
#   'agged_au_cat3_dum_C_mean': 0.92,
#   'agged_au_cat3_dum_nan_mean': 0.93,
#   'agged_au_purchase_date_all_weeks_ptp': 0.8,
#   'agged_au_purchase_date_all_weeks_min': 0.8,
#   'agged_au_purchase_date_all_weeks_mean': 0.81,
#   'agged_au_purchase_date_all_weeks_max': 0.8,
#   'agged_au_purchase_date_all_weeks_std': 0.18,
#   'agged_au_purchase_amount_unusual_mean': 0.43,
#   'agged_au_purchase_amount_unusual_sum': 0.73,
#   'agged_au_purchase_date_year_mean': 0.96,
#   'agged_au_purchase_date_year_max': 0.38,
#   'agged_au_purchase_date_year_min': 0.2,
#   'agged_au_purchase_date_season_mean': 0.96,
#   'agged_au_purchase_date_season_modeplus': 0.24,
#   'agged_au_purchase_date_season_std': 0.4,
#   'agged_au_purchase_date_activity_month_mean': 0.93,
#   'agged_au_purchase_date_activity_month_max': 0.8,
#   'agged_au_purchase_date_activity_month_min': 0.63,
#   'agged_au_purchase_date_activity_month_std': 0.66,
#   'agged_au_purchase_date_activity_month_ptp': 0.92,
#   'agged_au_purchase_date_month_mean': 0.94,
#   'agged_au_purchase_date_month_max': 0.39,
#   'agged_au_purchase_date_month_min': 0.38,
#   'agged_au_purchase_date_month_std': 0.3,
#   'agged_au_purchase_date_week_mean': 0.81,
#   'agged_au_purchase_date_week_max': 0.32,
#   'agged_au_purchase_date_week_min': 0.39,
#   'agged_au_purchase_date_week_std': 0.3,
#   'agged_au_purchase_date_months_week_mean': 0.33,
#   'agged_au_purchase_date_months_week_std': 0.36,
#   'agged_au_purchase_date_months_week_max': 0.06,
#   'agged_au_purchase_date_months_week_min': 0.37,
#   'agged_au_purchase_date_end_of_the_month_mean': 0.4,
#   'agged_au_purchase_years_day_mean': 0.77,
#   'agged_au_purchase_years_day_max': 0.78,
#   'agged_au_purchase_years_day_min': 0.78,
#   'agged_au_purchase_years_day_std': 0.24,
#   'agged_au_purchase_years_day_ptp': 0.78,
#   'agged_au_purchase_date_day_mean': 0.78,
#   'agged_au_purchase_date_day_std': 0.18,
#   'agged_au_purchase_date_day_max': 0.18,
#   'agged_au_purchase_date_day_min': 0.17,
#   'agged_au_purchase_date_weekend_mean': 0.38,
#   'agged_au_purchase_date_hour_mean': 0.32,
#   'agged_au_purchase_date_hour_std': 0.22,
#   'agged_au_purchase_date_hour_max': 0.27,
#   'agged_au_purchase_date_hour_min': 0.23,
#   'agged_au_purchase_date_day_cycle_mean': 0.32,
#   'agged_au_payment_per_month_sum': 0.49,
#   'agged_au_payment_per_month_mean': 0.23,
#   'agged_au_payment_per_month_std': 0.19,
#   'agged_au_number_of_purchases_max': 0.55,
#   'agged_au_valid_authorization_percent_max': 0.92,
#   'agged_au_payment_from_end_to_begging_mean': 0.82,
#   'agged_au_payment_from_end_to_begging_max': 0.92,
#   'agged_au_payment_from_end_to_begging_min': 0.93,
#   'agged_au_purchase_date_start_of_the_month_mean': 0.36,
#   'agged_au_position_from_start_to_finnish_mean': 0.94,
#   'agged_au_position_from_start_to_finnish_ptp': 0.81,
#   'agged_au_position_from_start_to_finnish_max': 0.96,
#   'agged_au_position_from_start_to_finnish_min': 0.83,
#   'agged_au_debt_until_month_mean': 0.91,
#   'agged_au_debt_until_month_std': 0.34,
#   'agged_au_debt_until_month_ptp': 0.33,
#   'agged_non_transactions_count': 0.57,
#   'agged_non_category_1_sum': 0.85,
#   'agged_non_category_1_mean': 0.36,
#   'agged_non_purchase_date_year_quarter_mean': 0.88,
#   'agged_non_purchase_date_year_quarter_median': 0.19,
#   'agged_non_city_id_modeplus': 0.2,
#   'agged_non_city_id_nunique': 0.12,
#   'agged_non_installments_sum': 0.8,
#   'agged_non_installments_mean': 0.81,
#   'agged_non_installments_max': 0.12,
#   'agged_non_installments_min': 0.24,
#   'agged_non_installments_std': 0.29,
#   'agged_non_installments_nunique': 0.28,
#   'agged_non_merchant_category_id_modeplus': 0.19,
#   'agged_non_merchant_category_id_nunique': 0.14,
#   'agged_non_month_lag_mean': 0.81,
#   'agged_non_month_lag_max': 0.69,
#   'agged_non_month_lag_min': 0.74,
#   'agged_non_month_lag_std': 0.76,
#   'agged_non_purchase_amount_sum': 0.46,
#   'agged_non_purchase_amount_mean': 0.02,
#   'agged_non_purchase_amount_max': 0.06,
#   'agged_non_purchase_amount_min': 0.02,
#   'agged_non_purchase_amount_std': 0.02,
#   'agged_non_state_id_modeplus': 0.29,
#   'agged_non_state_id_nunique': 0.3,
#   'agged_non_subsector_id_modeplus': 0.07,
#   'agged_non_subsector_id_nunique': 0.02,
#   'agged_non_no_city_mean': 0.41,
#   'agged_non_no_city_sum': 0.87,
#   'agged_non_undefined_installments_mean': 0.75,
#   'agged_non_undefined_installments_sum': 0.86,
#   'agged_non_undefined_installments_min': 0.37,
#   'agged_non_undefined_installments_max': 0.37,
#   'agged_non_big_installments_mean': 0.44,
#   'agged_non_big_installments_sum': 0.99,
#   'agged_non_big_installments_min': 0.44,
#   'agged_non_big_installments_max': 1.0,
#   'agged_non_cat2_dum_0.0_mean': 0.67,
#   'agged_non_cat2_dum_1.0_mean': 0.67,
#   'agged_non_cat2_dum_2.0_mean': 0.66,
#   'agged_non_cat2_dum_3.0_mean': 0.66,
#   'agged_non_cat2_dum_4.0_mean': 0.67,
#   'agged_non_cat2_dum_5.0_mean': 0.67,
#   'agged_non_cat2_dum_nan_mean': 0.02,
#   'agged_non_cat3_dum_A_mean': 0.74,
#   'agged_non_cat3_dum_B_mean': 0.74,
#   'agged_non_cat3_dum_C_mean': 0.74,
#   'agged_non_cat3_dum_nan_mean': 0.75,
#   'agged_non_purchase_date_all_weeks_ptp': 0.57,
#   'agged_non_purchase_date_all_weeks_min': 0.58,
#   'agged_non_purchase_date_all_weeks_mean': 0.7,
#   'agged_non_purchase_date_all_weeks_max': 0.57,
#   'agged_non_purchase_date_all_weeks_std': 0.35,
#   'agged_non_purchase_amount_unusual_mean': 0.28,
#   'agged_non_purchase_amount_unusual_sum': 0.73,
#   'agged_non_purchase_date_year_mean': 0.89,
#   'agged_non_purchase_date_year_max': 0.43,
#   'agged_non_purchase_date_year_min': 0.41,
#   'agged_non_purchase_date_season_mean': 0.88,
#   'agged_non_purchase_date_season_modeplus': 0.25,
#   'agged_non_purchase_date_season_std': 0.36,
#   'agged_non_purchase_date_activity_month_mean': 0.78,
#   'agged_non_purchase_date_activity_month_max': 0.81,
#   'agged_non_purchase_date_activity_month_min': 0.66,
#   'agged_non_purchase_date_activity_month_std': 0.76,
#   'agged_non_purchase_date_activity_month_ptp': 0.87,
#   'agged_non_purchase_date_month_mean': 0.71,
#   'agged_non_purchase_date_month_max': 0.17,
#   'agged_non_purchase_date_month_min': 0.22,
#   'agged_non_purchase_date_month_std': 0.3,
#   'agged_non_purchase_date_week_mean': 0.7,
#   'agged_non_purchase_date_week_max': 0.17,
#   'agged_non_purchase_date_week_min': 0.13,
#   'agged_non_purchase_date_week_std': 0.27,
#   'agged_non_purchase_date_months_week_mean': 0.33,
#   'agged_non_purchase_date_months_week_std': 0.31,
#   'agged_non_purchase_date_months_week_max': 0.31,
#   'agged_non_purchase_date_months_week_min': 0.32,
#   'agged_non_purchase_date_end_of_the_month_mean': 0.38,
#   'agged_non_purchase_years_day_mean': 0.54,
#   'agged_non_purchase_years_day_max': 0.61,
#   'agged_non_purchase_years_day_min': 0.61,
#   'agged_non_purchase_years_day_std': 0.17,
#   'agged_non_purchase_years_day_ptp': 0.61,
#   'agged_non_purchase_date_day_mean': 0.54,
#   'agged_non_purchase_date_day_std': 0.24,
#   'agged_non_purchase_date_day_max': 0.16,
#   'agged_non_purchase_date_day_min': 0.2,
#   'agged_non_purchase_date_weekend_mean': 0.1,
#   'agged_non_purchase_date_hour_mean': 0.14,
#   'agged_non_purchase_date_hour_std': 0.09,
#   'agged_non_purchase_date_hour_max': 0.16,
#   'agged_non_purchase_date_hour_min': 0.09,
#   'agged_non_purchase_date_day_cycle_mean': 0.33,
#   'agged_non_payment_per_month_sum': 0.49,
#   'agged_non_payment_per_month_mean': 0.02,
#   'agged_non_payment_per_month_std': 0.01,
#   'agged_non_number_of_purchases_max': 0.03,
#   'agged_non_valid_authorization_percent_max': 0.85,
#   'agged_non_payment_from_end_to_begging_mean': 0.59,
#   'agged_non_payment_from_end_to_begging_max': 0.87,
#   'agged_non_payment_from_end_to_begging_min': 0.87,
#   'agged_non_purchase_date_start_of_the_month_mean': 0.36,
#   'agged_non_position_from_start_to_finnish_mean': 0.77,
#   'agged_non_position_from_start_to_finnish_ptp': 0.82,
#   'agged_non_position_from_start_to_finnish_max': 0.82,
#   'agged_non_position_from_start_to_finnish_min': 0.85,
#   'agged_non_debt_until_month_mean': 0.81,
#   'agged_non_debt_until_month_std': 0.23,
#   'agged_non_debt_until_month_ptp': 0.2,
#   '0to1_rel_gen_mean': 0.43,
#   '1to2_rel_gen_mean': 0.15,
#   '2to3_rel_gen_mean': 0.23,
#   '3to4_rel_gen_mean': 0.22,
#   '4to5_rel_gen_mean': 0.21,
#   '5to6_rel_gen_mean': 0.15,
#   '6to7_rel_gen_mean': 0.16,
#   '7to8_rel_gen_mean': 0.09,
#   '8to9_rel_gen_mean': 0.07,
#   '9to10_rel_gen_mean': 0.08,
#   '10to11_rel_gen_mean': 0.15,
#   '11to12_rel_gen_mean': 0.15,
#   '12to13_rel_gen_mean': 0.27,
#   '13to14_rel_gen_mean': 0.17,
#   '14to15_rel_gen_mean': 0.15,
#   '0to1_rel_mean': 0.41,
#   '1to2_rel_mean': 0.12,
#   '2to3_rel_mean': 0.22,
#   '3to4_rel_mean': 0.22,
#   '4to5_rel_mean': 0.21,
#   '5to6_rel_mean': 0.03,
#   '6to7_rel_mean': 0.01,
#   '7to8_rel_mean': 0.16,
#   '8to9_rel_mean': 0.15,
#   '9to10_rel_mean': 0.15,
#   '10to11_rel_mean': 0.25,
#   '11to12_rel_mean': 0.08,
#   '12to13_rel_mean': 0.27,
#   '13to14_rel_mean': 0.25,
#   '14to15_rel_mean': 0.13,
#   'transactions_count': 0.55,
#   '0th_month_debt_bte_sum': 0.0,
#   '0th_month_debt_bte_mean': 0.0,
#   '0th_month_debt_bte_std': 0.0,
#   '1th_month_debt_bte_sum': 0.01,
#   '1th_month_debt_bte_mean': 0.1,
#   '1th_month_debt_bte_std': 0.08,
#   '2th_month_debt_bte_sum': 0.04,
#   '2th_month_debt_bte_mean': 0.13,
#   '2th_month_debt_bte_std': 0.13,
#   '3th_month_debt_bte_sum': 0.02,
#   '3th_month_debt_bte_mean': 0.1,
#   '3th_month_debt_bte_std': 0.12,
#   '4th_month_debt_bte_sum': 0.04,
#   '4th_month_debt_bte_mean': 0.13,
#   '4th_month_debt_bte_std': 0.13,
#   '5th_month_debt_bte_sum': 0.06,
#   '5th_month_debt_bte_mean': 0.11,
#   '5th_month_debt_bte_std': 0.08,
#   '6th_month_debt_bte_sum': 0.04,
#   '6th_month_debt_bte_mean': 0.18,
#   '6th_month_debt_bte_std': 0.18,
#   '7th_month_debt_bte_sum': 0.0,
#   '7th_month_debt_bte_mean': 0.12,
#   '7th_month_debt_bte_std': 0.09,
#   '8th_month_debt_bte_sum': 0.04,
#   '8th_month_debt_bte_mean': 0.11,
#   '8th_month_debt_bte_std': 0.03,
#   '9th_month_debt_bte_sum': 0.05,
#   '9th_month_debt_bte_mean': 0.1,
#   '9th_month_debt_bte_std': 0.07,
#   '10th_month_debt_bte_sum': 0.05,
#   '10th_month_debt_bte_mean': 0.11,
#   '10th_month_debt_bte_std': 0.05,
#   '11th_month_debt_bte_sum': 0.05,
#   '11th_month_debt_bte_mean': 0.11,
#   '11th_month_debt_bte_std': 0.06,
#   '12th_month_debt_bte_sum': 0.01,
#   '12th_month_debt_bte_mean': 0.11,
#   '12th_month_debt_bte_std': 0.03,
#   '13th_month_debt_bte_sum': 0.06,
#   '13th_month_debt_bte_mean': 0.07,
#   '13th_month_debt_bte_std': 0.1,
#   '14th_month_debt_bte_sum': 0.07,
#   '14th_month_debt_bte_mean': 0.11,
#   '14th_month_debt_bte_std': 0.07,
#   '15th_month_debt_bte_sum': 0.06,
#   '15th_month_debt_bte_mean': 0.12,
#   '15th_month_debt_bte_std': 0.25,
#   '16th_month_debt_bte_sum': 0.04,
#   '16th_month_debt_bte_mean': 0.35,
#   '16th_month_debt_bte_std': 0.35,
#   '17th_month_debt_bte_sum': 0.19,
#   '17th_month_debt_bte_mean': 0.3,
#   '17th_month_debt_bte_std': 0.25,
#   '18th_month_debt_bte_sum': 0.14,
#   '18th_month_debt_bte_mean': 0.4,
#   '18th_month_debt_bte_std': 0.35,
#   '19th_month_debt_bte_sum': 0.14,
#   '19th_month_debt_bte_mean': 0.34,
#   '19th_month_debt_bte_std': 0.34,
#   '20th_month_debt_bte_sum': 0.03,
#   '20th_month_debt_bte_mean': 0.35,
#   '20th_month_debt_bte_std': 0.25,
#   '21th_month_debt_bte_sum': 0.19,
#   '21th_month_debt_bte_mean': 0.37,
#   '21th_month_debt_bte_std': 0.37,
#   '22th_month_debt_bte_sum': 0.2,
#   '22th_month_debt_bte_mean': 0.34,
#   '22th_month_debt_bte_std': 0.34,
#   '23th_month_debt_bte_sum': 0.26,
#   '23th_month_debt_bte_mean': 0.4,
#   '23th_month_debt_bte_std': 0.27,
#   '24th_month_debt_bte_sum': 0.22,
#   '24th_month_debt_bte_mean': 0.34,
#   '24th_month_debt_bte_std': 0.41,
#   '25th_month_debt_bte_sum': 0.01,
#   '25th_month_debt_bte_mean': 0.41,
#   '25th_month_debt_bte_std': 0.41,
#   '26th_month_debt_bte_sum': 0.2,
#   '26th_month_debt_bte_mean': 0.42,
#   '26th_month_debt_bte_std': 0.43,
#   '27th_month_debt_bte_sum': 0.39,
#   '27th_month_debt_bte_mean': 0.42,
#   '27th_month_debt_bte_std': 0.42,
#   '28th_month_debt_bte_sum': 0.45,
#   '28th_month_debt_bte_mean': 0.45,
#   '28th_month_debt_bte_std': 0.45,
#   'last_purchase_month_bins': 0.4,
#   'feature_1_pr': 0.44,
#   'feature_2_pr': 0.44,
#   'feature_3_pr': 0.96}}

# %%
# Using Linear Regression
lr = LinearRegression(normalize=True)
lr.fit(X,Y)
ranks["LinReg"] = ranking(np.abs(lr.coef_), colnames)

# Using Ridge 
ridge = Ridge(alpha = 7)
ridge.fit(X,Y)
ranks['Ridge'] = ranking(np.abs(ridge.coef_), colnames)

# Using Lasso
lasso = Lasso(alpha=.05)
lasso.fit(X, Y)
ranks["Lasso"] = ranking(np.abs(lasso.coef_), colnames)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-dc7e72df27ed> in <module>
#       2 lr = LinearRegression(normalize=True)
#       3 lr.fit(X,Y)
# ----> 4 ranks["LinReg"] = ranking(np.abs(lr.coef_), colnames)
#       5
#       6 # Using Ridge
#
# <ipython-input-32-2e8ae92191da> in ranking(ranks, names, order)
#       4 def ranking(ranks, names, order=1):
#       5     minmax = MinMaxScaler()
# ----> 6     ranks = minmax.fit_transform(order*np.array([ranks]).T).T[0]
#       7     ranks = map(lambda x: round(x,2), ranks)
#       8     return dict(zip(names, ranks))
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     460         if y is None:
#     461             # fit method of arity 1 (unsupervised transformation)
# --> 462             return self.fit(X, **fit_params).transform(X)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     321         # Reset internal state before fitting
#     322         self._reset()
# --> 323         return self.partial_fit(X, y)
#     324
#     325     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in partial_fit(self, X, y)
#     349         X = check_array(X, copy=self.copy, warn_on_dtype=True,
#     350                         estimator=self, dtype=FLOAT_DTYPES,
# --> 351                         force_all_finite="allow-nan")
#     352
#     353         data_min = np.nanmin(X, axis=0)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     563         if not allow_nd and array.ndim >= 3:
#     564             raise ValueError("Found array with dim %d. %s expected <= 2."
# --> 565                              % (array.ndim, estimator_name))
#     566         if force_all_finite:
#     567             _assert_all_finite(array,
#
# ValueError: Found array with dim 3. MinMaxScaler expected <= 2.

# %% [markdown]
# # 5. Random Forest feature ranking
#
# Sklearn's Random Forest model also comes with it's own inbuilt feature ranking attribute and one can conveniently just call it via "feature_importances_". That is what we will be using as follows:

# %%
rf = RandomForestRegressor(n_jobs=-1, n_estimators=50, verbose=3)
rf.fit(X,Y)
ranks["RF"] = ranking(rf.feature_importances_, colnames);

# %% [markdown]
# # 6. Creating the Feature Ranking Matrix
#
# We combine the scores from the various methods above and output it in a matrix form for convenient viewing as such:

# %%
# Create empty dictionary to store the mean value calculated from all the scores
r = {}
for name in colnames:
    r[name] = round(np.mean([ranks[method][name] 
                             for method in ranks.keys()]), 2)
 
methods = sorted(ranks.keys())
ranks["Mean"] = r
methods.append("Mean")
 
print("\t%s" % "\t".join(methods))
for name in colnames:
    print("%s\t%s" % (name, "\t".join(map(str, 
                         [ranks[method][name] for method in methods]))))

# %% [markdown]
# Now, with the matrix above, the numbers and layout does not seem very easy or pleasant to the eye. Therefore, let's just collate the mean ranking score attributed to each of the feature and plot that via Seaborn's factorplot.

# %%
# Put the mean scores into a Pandas dataframe
meanplot = pd.DataFrame(list(r.items()), columns= ['Feature','Mean Ranking'])

# Sort the dataframe
meanplot = meanplot.sort_values('Mean Ranking', ascending=False)

# %%
# Let's plot the ranking of the features
sns.factorplot(x="Mean Ranking", y="Feature", data = meanplot, kind="bar", 
               size=14, aspect=1.9, palette='coolwarm')

# %% [markdown]
# Well as you can see from our feature ranking endeavours, the top 3 features are 'lat', 'waterfront' and 'grade'. The bottom 3 are 'sqft_lot15', 'sqft_lot' and 'sqft_basement'.
# This sort of feature ranking can be really useful, especially if one has many many features in the dataset and would like to trim or cut off features that contribute negligibly.
